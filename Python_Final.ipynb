# %%
import pandas as pd

# %%
with open('scorecard_bat_1_Aussies.csv', 'rb') as file:
    byte_string = file.read()
    try:
        decoded_string = byte_string.decode('utf-8')
        # do something with the decoded string
    except UnicodeDecodeError:
        # try decoding with a different encoding
        decoded_string = byte_string.decode('cp1252')
        # do something with the decoded string

# %%
df_as_2_bat = pd.read_csv('scorecard_bat_2_Aussies.csv',encoding='cp1252')
df_as_1_bat = pd.read_csv('scorecard_bat_1_Aussies.csv',encoding='cp1252')
df_as_3_bat = pd.read_csv('scorecard_bat_3_Aussies.csv',encoding='cp1252')

# %%
df_nz_2_bat = pd.read_csv('Scorecard_bat_2_newz.csv',encoding='cp1252')
df_nz_1_bat = pd.read_csv('Scorecard_bat_1_NZ.csv',encoding='cp1252')
df_nz_3_bat = pd.read_csv('Scorecard_bat_3_NZ.csv',encoding='cp1252')

# %%
df_sa_2_bat = pd.read_csv('Scorecard_bat_2_SA.csv',encoding='cp1252')
df_sa_1_bat = pd.read_csv('Scorecard_bat_1_SA.csv',encoding='cp1252')
df_sa_3_bat = pd.read_csv('Scorecard_bat_3_SA.csv',encoding='cp1252')

# %%
df_as_2_bowl = pd.read_csv('scorecard_bowl_2_Aussies.csv',encoding='cp1252')
df_as_1_bowl = pd.read_csv('scorecard_bowl_1_Aussies.csv',encoding='cp1252')
df_as_3_bowl = pd.read_csv('scorecard_bowl_3_Aussies.csv',encoding='cp1252')

# %%
df_nz_2_bowl = pd.read_csv('Scorecard_bowl_2_NZ.csv',encoding='cp1252')
df_nz_1_bowl = pd.read_csv('Scorecard_bowl_1_NZ.csv',encoding='cp1252')
df_nz_3_bowl = pd.read_csv('Scorecard_bowl_3_NZ.csv',encoding='cp1252')

# %%
df_sa_2_bowl = pd.read_csv('scorecard_bowl_2_SA.csv',encoding='cp1252')
df_sa_1_bowl = pd.read_csv('scorecard_bowl_1_SA.csv',encoding='cp1252')
df_sa_3_bowl = pd.read_csv('scorecard_bowl_3_SA.csv',encoding='cp1252')

# %%
df_sa_1_bat
# Out:
#                                                Player             Dismissal  \
# 0                                    Shikhar Dhawan *             b Parnell
# 1                                        Shubman Gill              b Rabada
# 2   Ruturaj Gaikwad\nâ€’â€’â€’â€’â€’â€’â€’â€’â€’â€...  st tde Kock b Shamsi
# 3                                        Ishan Kishan     c Malan b Maharaj
# 4                                        Shreyas Iyer      c Rabada b Ngidi
# 5   Sanju Samsont\nâ€’â€’â€’â€’â€’â€’â€’â€’â€’â€’â...               not out
# 6                                      Shardul Thakur     c Maharaj b Ngidi
# 7                                       Kuldeep Yadav      c Bavuma b Ngidi
# 8                                          Avesh Khan     c Bavuma b Rabada
# 9                                        Ravi Bishnoi               not out
# 10  Mohammed Siraj -------------------------------...                   NaN
#
#     Runs Balls Faced Fours  Sixes  Strike Rate
# ...

# %%
df_sa_1_bat['Player'] = df_sa_1_bat['Player'].replace({'â€': ''}, regex=True)
df_sa_1_bat
# Out:
#                                                Player             Dismissal  \
# 0                                    Shikhar Dhawan *             b Parnell
# 1                                        Shubman Gill              b Rabada
# 2                Ruturaj Gaikwad\n’’’’’’’’’’’’’’’’’’’  st tde Kock b Shamsi
# 3                                        Ishan Kishan     c Malan b Maharaj
# 4                                        Shreyas Iyer      c Rabada b Ngidi
# 5                       Sanju Samsont\n’’’’’’’’’’’’’’               not out
# 6                                      Shardul Thakur     c Maharaj b Ngidi
# 7                                       Kuldeep Yadav      c Bavuma b Ngidi
# 8                                          Avesh Khan     c Bavuma b Rabada
# 9                                        Ravi Bishnoi               not out
# 10  Mohammed Siraj -------------------------------...                   NaN
#
#     Runs Balls Faced Fours  Sixes  Strike Rate
# ...

# %%
df_sa_1_bat['Player'] = df_sa_1_bat['Player'].replace({'\n’’’’’’’’’’’’’’’’’’’': ''}, regex=True)
df_sa_1_bat
# Out:
#                                                Player             Dismissal  \
# 0                                    Shikhar Dhawan *             b Parnell
# 1                                        Shubman Gill              b Rabada
# 2                                     Ruturaj Gaikwad  st tde Kock b Shamsi
# 3                                        Ishan Kishan     c Malan b Maharaj
# 4                                        Shreyas Iyer      c Rabada b Ngidi
# 5                       Sanju Samsont\n’’’’’’’’’’’’’’               not out
# 6                                      Shardul Thakur     c Maharaj b Ngidi
# 7                                       Kuldeep Yadav      c Bavuma b Ngidi
# 8                                          Avesh Khan     c Bavuma b Rabada
# 9                                        Ravi Bishnoi               not out
# 10  Mohammed Siraj -------------------------------...                   NaN
#
#     Runs Balls Faced Fours  Sixes  Strike Rate
# ...

# %%
import re
df_sa_1_bat['Player'] = df_sa_1_bat['Player'].replace('[^a-zA-Z ]', '', regex=True)
df_sa_1_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours  Sixes  \
# 0    Shikhar Dhawan              b Parnell   4.0          16     O    0.0
# 1       Shubman Gill              b Rabada   3.0           7     0    0.0
# 2    Ruturaj Gaikwad  st tde Kock b Shamsi  19.0       42 Â£     1    0.0
# 3       Ishan Kishan     c Malan b Maharaj  20.0        w 37     3    0.0
# 4       Shreyas Iyer      c Rabada b Ngidi  50.0        37 w     8    0.0
# 5      Sanju Samsont               not out  86.0          63     9    3.0
# 6     Shardul Thakur     c Maharaj b Ngidi  33.0       wa 31     5    0.0
# 7      Kuldeep Yadav      c Bavuma b Ngidi   0.0           1     0    0.0
# 8         Avesh Khan     c Bavuma b Rabada   3.0           6     0    0.0
# 9       Ravi Bishnoi               not out   4.0           2     0    0.0
# 10  Mohammed Siraj                     NaN   NaN         NaN   NaN    NaN
#
#     Strike Rate
# 0         25.00
# 1         42.86
# 2         45.24
# ...

# %%
df_sa_1_bat.at[5, 'Player'] = df_sa_1_bat.at[5, 'Player'].replace('t', '')
df_sa_1_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours  Sixes  \
# 0    Shikhar Dhawan              b Parnell   4.0          16     O    0.0
# 1       Shubman Gill              b Rabada   3.0           7     0    0.0
# 2    Ruturaj Gaikwad  st tde Kock b Shamsi  19.0       42 Â£     1    0.0
# 3       Ishan Kishan     c Malan b Maharaj  20.0        w 37     3    0.0
# 4       Shreyas Iyer      c Rabada b Ngidi  50.0        37 w     8    0.0
# 5       Sanju Samson               not out  86.0          63     9    3.0
# 6     Shardul Thakur     c Maharaj b Ngidi  33.0       wa 31     5    0.0
# 7      Kuldeep Yadav      c Bavuma b Ngidi   0.0           1     0    0.0
# 8         Avesh Khan     c Bavuma b Rabada   3.0           6     0    0.0
# 9       Ravi Bishnoi               not out   4.0           2     0    0.0
# 10  Mohammed Siraj                     NaN   NaN         NaN   NaN    NaN
#
#     Strike Rate
# 0         25.00
# 1         42.86
# 2         45.24
# ...

# %%
df_sa_1_bat['Balls Faced'] = df_sa_1_bat['Balls Faced'].str.extract('(\d+)', expand=False)
df_sa_1_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours  Sixes  \
# 0    Shikhar Dhawan              b Parnell   4.0          16     O    0.0
# 1       Shubman Gill              b Rabada   3.0           7     0    0.0
# 2    Ruturaj Gaikwad  st tde Kock b Shamsi  19.0          42     1    0.0
# 3       Ishan Kishan     c Malan b Maharaj  20.0          37     3    0.0
# 4       Shreyas Iyer      c Rabada b Ngidi  50.0          37     8    0.0
# 5       Sanju Samson               not out  86.0          63     9    3.0
# 6     Shardul Thakur     c Maharaj b Ngidi  33.0          31     5    0.0
# 7      Kuldeep Yadav      c Bavuma b Ngidi   0.0           1     0    0.0
# 8         Avesh Khan     c Bavuma b Rabada   3.0           6     0    0.0
# 9       Ravi Bishnoi               not out   4.0           2     0    0.0
# 10  Mohammed Siraj                     NaN   NaN         NaN   NaN    NaN
#
#     Strike Rate
# 0         25.00
# 1         42.86
# 2         45.24
# ...

# %%
df_sa_1_bat[['Runs', 'Balls Faced', 'Fours', 'Sixes', 'Strike Rate']] = df_sa_1_bat[['Runs', 'Balls Faced', 'Fours', 'Sixes', 'Strike Rate']].fillna(value=0)

df_sa_1_bat['Dismissal'].fillna('-', inplace = True)
df_sa_1_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours  Sixes  \
# 0    Shikhar Dhawan              b Parnell   4.0          16     O    0.0
# 1       Shubman Gill              b Rabada   3.0           7     0    0.0
# 2    Ruturaj Gaikwad  st tde Kock b Shamsi  19.0          42     1    0.0
# 3       Ishan Kishan     c Malan b Maharaj  20.0          37     3    0.0
# 4       Shreyas Iyer      c Rabada b Ngidi  50.0          37     8    0.0
# 5       Sanju Samson               not out  86.0          63     9    3.0
# 6     Shardul Thakur     c Maharaj b Ngidi  33.0          31     5    0.0
# 7      Kuldeep Yadav      c Bavuma b Ngidi   0.0           1     0    0.0
# 8         Avesh Khan     c Bavuma b Rabada   3.0           6     0    0.0
# 9       Ravi Bishnoi               not out   4.0           2     0    0.0
# 10  Mohammed Siraj                       -   0.0           0     0    0.0
#
#     Strike Rate
# 0         25.00
# 1         42.86
# 2         45.24
# ...

# %%
df_sa_2_bat
# Out:
#                Player              Dismissal   Runs  Balls Faced  Fours  \
# 0        Shubman Gill           c & b Rabada   28.0         26.0    4.0
# 1        Ishan Kishan  c Hendricks b Fortuin   93.0         84.0    4.0
# 2        Shreyas Iyer                not out  113.0        111.0   15.0
# 3     Sanju Samsonâ€                 not out   30.0         36.0    1.0
# 4      Shardul Thakur                    NaN    NaN          NaN    NaN
# 5   Washington Sundar                    NaN    NaN          NaN    NaN
# 6       Shahbaz Ahmed                    NaN    NaN          NaN    NaN
# 7       Kuldeep Yadav                    NaN    NaN          NaN    NaN
# 8          Avesh Khan                    NaN    NaN          NaN    NaN
# 9          Avesh Khan                    NaN    NaN          NaN    NaN
# 10     Mohammed Siraj                    NaN    NaN          NaN    NaN
#
#     Sixes  Strike Rate
# 0     0.0       107.69
# 1     7.0       110.71
# 2     0.0       101.80
# ...

# %%
df_sa_2_bat[['Runs', 'Balls Faced', 'Fours', 'Sixes', 'Strike Rate']] = df_sa_2_bat[['Runs', 'Balls Faced', 'Fours', 'Sixes', 'Strike Rate']].fillna(value=0)

df_sa_2_bat['Dismissal'].fillna('-', inplace = True)
df_sa_2_bat
# Out:
#                Player              Dismissal   Runs  Balls Faced  Fours  \
# 0        Shubman Gill           c & b Rabada   28.0         26.0    4.0
# 1        Ishan Kishan  c Hendricks b Fortuin   93.0         84.0    4.0
# 2        Shreyas Iyer                not out  113.0        111.0   15.0
# 3     Sanju Samsonâ€                 not out   30.0         36.0    1.0
# 4      Shardul Thakur                      -    0.0          0.0    0.0
# 5   Washington Sundar                      -    0.0          0.0    0.0
# 6       Shahbaz Ahmed                      -    0.0          0.0    0.0
# 7       Kuldeep Yadav                      -    0.0          0.0    0.0
# 8          Avesh Khan                      -    0.0          0.0    0.0
# 9          Avesh Khan                      -    0.0          0.0    0.0
# 10     Mohammed Siraj                      -    0.0          0.0    0.0
#
#     Sixes  Strike Rate
# 0     0.0       107.69
# 1     7.0       110.71
# 2     0.0       101.80
# ...

# %%
df_sa_2_bat['Player'] = df_sa_2_bat['Player'].str.replace('\u20AC', '')
df_sa_2_bat
# Out:
#                Player              Dismissal   Runs  Balls Faced  Fours  \
# 0        Shubman Gill           c & b Rabada   28.0         26.0    4.0
# 1        Ishan Kishan  c Hendricks b Fortuin   93.0         84.0    4.0
# 2        Shreyas Iyer                not out  113.0        111.0   15.0
# 3      Sanju Samsonâ                 not out   30.0         36.0    1.0
# 4      Shardul Thakur                      -    0.0          0.0    0.0
# 5   Washington Sundar                      -    0.0          0.0    0.0
# 6       Shahbaz Ahmed                      -    0.0          0.0    0.0
# 7       Kuldeep Yadav                      -    0.0          0.0    0.0
# 8          Avesh Khan                      -    0.0          0.0    0.0
# 9          Avesh Khan                      -    0.0          0.0    0.0
# 10     Mohammed Siraj                      -    0.0          0.0    0.0
#
#     Sixes  Strike Rate
# 0     0.0       107.69
# 1     7.0       110.71
# 2     0.0       101.80
# ...

# %%
#data cleaned in sa_2_bat
df_sa_2_bat
# Out:
#                Player              Dismissal   Runs  Balls Faced  Fours  \
# 0        Shubman Gill           c & b Rabada   28.0         26.0    4.0
# 1        Ishan Kishan  c Hendricks b Fortuin   93.0         84.0    4.0
# 2        Shreyas Iyer                not out  113.0        111.0   15.0
# 3      Sanju Samsonâ                 not out   30.0         36.0    1.0
# 4      Shardul Thakur                      -    0.0          0.0    0.0
# 5   Washington Sundar                      -    0.0          0.0    0.0
# 6       Shahbaz Ahmed                      -    0.0          0.0    0.0
# 7       Kuldeep Yadav                      -    0.0          0.0    0.0
# 8          Avesh Khan                      -    0.0          0.0    0.0
# 9          Avesh Khan                      -    0.0          0.0    0.0
# 10     Mohammed Siraj                      -    0.0          0.0    0.0
#
#     Sixes  Strike Rate
# 0     0.0       107.69
# 1     7.0       110.71
# 2     0.0       101.80
# ...

# %%
#data cleaned in sa_1_bat
df_sa_1_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours  Sixes  \
# 0    Shikhar Dhawan              b Parnell   4.0          16     O    0.0
# 1       Shubman Gill              b Rabada   3.0           7     0    0.0
# 2    Ruturaj Gaikwad  st tde Kock b Shamsi  19.0          42     1    0.0
# 3       Ishan Kishan     c Malan b Maharaj  20.0          37     3    0.0
# 4       Shreyas Iyer      c Rabada b Ngidi  50.0          37     8    0.0
# 5       Sanju Samson               not out  86.0          63     9    3.0
# 6     Shardul Thakur     c Maharaj b Ngidi  33.0          31     5    0.0
# 7      Kuldeep Yadav      c Bavuma b Ngidi   0.0           1     0    0.0
# 8         Avesh Khan     c Bavuma b Rabada   3.0           6     0    0.0
# 9       Ravi Bishnoi               not out   4.0           2     0    0.0
# 10  Mohammed Siraj                       -   0.0           0     0    0.0
#
#     Strike Rate
# 0         25.00
# 1         42.86
# 2         45.24
# ...

# %%
df_sa_3_bat
# Out:
#               Player               Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Shubman Gill             lbw b Ngidi  49.0         57.0    8.0    0.0
# 1       Ishan Kishan  c â€ de Kock b Fortuin  10.0         18.0    2.0    0.0
# 2       Shreyas Iyer                 not out  28.0         23.0    3.0    2.0
# 3    Sanju Samsonâ€                  not out   2.0          4.0    0.0    0.0
# 4     Shardul Thakur                     NaN   NaN          NaN    NaN    NaN
# 5  Washington Sundar                     NaN   NaN          NaN    NaN    NaN
# 6      Shahbaz Ahmed                     NaN   NaN          NaN    NaN    NaN
# 7      Kuldeep Yadav                     NaN   NaN          NaN    NaN    NaN
# 8         Avesh Khan                     NaN   NaN          NaN    NaN    NaN
#
#    Strike Rate
# 0        85.96
# 1        55.56
# 2       121.74
# 3        50.00
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
df_sa_3_bat['Dismissal'].fillna('-',inplace=True)
df_sa_3_bat
# Out:
#               Player               Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Shubman Gill             lbw b Ngidi  49.0         57.0    8.0    0.0
# 1       Ishan Kishan  c â€ de Kock b Fortuin  10.0         18.0    2.0    0.0
# 2       Shreyas Iyer                 not out  28.0         23.0    3.0    2.0
# 3    Sanju Samsonâ€                  not out   2.0          4.0    0.0    0.0
# 4     Shardul Thakur                       -   NaN          NaN    NaN    NaN
# 5  Washington Sundar                       -   NaN          NaN    NaN    NaN
# 6      Shahbaz Ahmed                       -   NaN          NaN    NaN    NaN
# 7      Kuldeep Yadav                       -   NaN          NaN    NaN    NaN
# 8         Avesh Khan                       -   NaN          NaN    NaN    NaN
#
#    Strike Rate
# 0        85.96
# 1        55.56
# 2       121.74
# 3        50.00
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
df_sa_3_bat.replace('â€', '', regex=True, inplace=True)
df_sa_3_bat
# Out:
#               Player             Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Shubman Gill           lbw b Ngidi  49.0         57.0    8.0    0.0
# 1       Ishan Kishan  c  de Kock b Fortuin  10.0         18.0    2.0    0.0
# 2       Shreyas Iyer               not out  28.0         23.0    3.0    2.0
# 3      Sanju Samson                not out   2.0          4.0    0.0    0.0
# 4     Shardul Thakur                     -   NaN          NaN    NaN    NaN
# 5  Washington Sundar                     -   NaN          NaN    NaN    NaN
# 6      Shahbaz Ahmed                     -   NaN          NaN    NaN    NaN
# 7      Kuldeep Yadav                     -   NaN          NaN    NaN    NaN
# 8         Avesh Khan                     -   NaN          NaN    NaN    NaN
#
#    Strike Rate
# 0        85.96
# 1        55.56
# 2       121.74
# 3        50.00
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
df_sa_3_bat['Balls Faced'] = df_sa_3_bat['Balls Faced'].fillna('0')
df_sa_3_bat
# Out:
#               Player             Dismissal  Runs Balls Faced  Fours  Sixes  \
# 0       Shubman Gill           lbw b Ngidi  49.0        57.0    8.0    0.0
# 1       Ishan Kishan  c  de Kock b Fortuin  10.0        18.0    2.0    0.0
# 2       Shreyas Iyer               not out  28.0        23.0    3.0    2.0
# 3      Sanju Samson                not out   2.0         4.0    0.0    0.0
# 4     Shardul Thakur                     -   NaN           0    NaN    NaN
# 5  Washington Sundar                     -   NaN           0    NaN    NaN
# 6      Shahbaz Ahmed                     -   NaN           0    NaN    NaN
# 7      Kuldeep Yadav                     -   NaN           0    NaN    NaN
# 8         Avesh Khan                     -   NaN           0    NaN    NaN
#
#    Strike Rate
# 0        85.96
# 1        55.56
# 2       121.74
# 3        50.00
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
df_sa_3_bat['Fours'] = df_sa_3_bat['Fours'].fillna('0')
df_sa_3_bat['Sixes'] = df_sa_3_bat['Sixes'].fillna('0')
df_sa_3_bat['Strike Rate'] = df_sa_3_bat['Strike Rate'].fillna('0')
df_sa_3_bat['Runs'] = df_sa_3_bat['Runs'].fillna('0')
df_sa_3_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours Sixes  \
# 0       Shubman Gill           lbw b Ngidi  49.0        57.0   8.0   0.0
# 1       Ishan Kishan  c  de Kock b Fortuin  10.0        18.0   2.0   0.0
# 2       Shreyas Iyer               not out  28.0        23.0   3.0   2.0
# 3      Sanju Samson                not out   2.0         4.0   0.0   0.0
# 4     Shardul Thakur                     -     0           0     0     0
# 5  Washington Sundar                     -     0           0     0     0
# 6      Shahbaz Ahmed                     -     0           0     0     0
# 7      Kuldeep Yadav                     -     0           0     0     0
# 8         Avesh Khan                     -     0           0     0     0
#
#   Strike Rate
# 0       85.96
# 1       55.56
# 2      121.74
# 3        50.0
# 4           0
# 5           0
# 6           0
# 7           0
# 8           0

# %%
#sa_3 match batting data cleaned
df_sa_3_bat
# Out:
#               Player             Dismissal  Runs Balls Faced Fours Sixes  \
# 0       Shubman Gill           lbw b Ngidi  49.0        57.0   8.0   0.0
# 1       Ishan Kishan  c  de Kock b Fortuin  10.0        18.0   2.0   0.0
# 2       Shreyas Iyer               not out  28.0        23.0   3.0   2.0
# 3      Sanju Samson                not out   2.0         4.0   0.0   0.0
# 4     Shardul Thakur                     -     0           0     0     0
# 5  Washington Sundar                     -     0           0     0     0
# 6      Shahbaz Ahmed                     -     0           0     0     0
# 7      Kuldeep Yadav                     -     0           0     0     0
# 8         Avesh Khan                     -     0           0     0     0
#
#   Strike Rate
# 0       85.96
# 1       55.56
# 2      121.74
# 3        50.0
# 4           0
# 5           0
# 6           0
# 7           0
# 8           0

# %%
df_nz_1_bat
# Out:
#                Player               Dismissal  Runs  Balls Faced  Fours  \
# 0       Rohit Sharma*    c Mitchell b Tickner    34           38      4
# 1        Shubman Gill    c Phillips b Shipley   208          149     19
# 2         Virat Kohli               b Santner     8           10      1
# 3     Ishan Kishanâ€   c â€ Latham b Ferguson     5           14      0
# 4    Suryakumar Yadav    c Santner b Mitchell    31           26      4
# 5       Hardik Pandya              b Mitchell    28           38      3
# 6   Washington Sundar           lbw b Shipley    12           14      0
# 7      Shardul Thakur                 run out     3            3      0
# 8       Kuldeep Yadav                 not out     5            6      0
# 9      Mohammed Shami                 not out     2            2      0
# 10     Mohammed Siraj                       -     0            0      0
#
#     Sixes  Strike Rate
# 0       2        89.47
# 1       9       139.60
# 2       0        80.00
# ...

# %%
df_nz_1_bat.replace('â€', '', regex=True, inplace=True)
df_nz_1_bat
# Out:
#                Player             Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Rohit Sharma*  c Mitchell b Tickner    34           38      4      2
# 1        Shubman Gill  c Phillips b Shipley   208          149     19      9
# 2         Virat Kohli             b Santner     8           10      1      0
# 3       Ishan Kishan   c  Latham b Ferguson     5           14      0      0
# 4    Suryakumar Yadav  c Santner b Mitchell    31           26      4      0
# 5       Hardik Pandya            b Mitchell    28           38      3      0
# 6   Washington Sundar         lbw b Shipley    12           14      0      0
# 7      Shardul Thakur               run out     3            3      0      0
# 8       Kuldeep Yadav               not out     5            6      0      0
# 9      Mohammed Shami               not out     2            2      0      0
# 10     Mohammed Siraj                     -     0            0      0      0
#
#     Strike Rate
# 0         89.47
# ...

# %%
df_nz_1_bat.describe()
# Out:
#              Runs  Balls Faced      Fours      Sixes  Strike Rate
# count   11.000000    11.000000  11.000000  11.000000    11.000000
# mean    30.545455    27.272727   2.818182   1.000000    82.430000
# std     60.143767    42.572505   5.618152   2.720294    37.896068
# min      0.000000     0.000000   0.000000   0.000000     0.000000
# 25%      4.000000     4.500000   0.000000   0.000000    76.840000
# 50%      8.000000    14.000000   0.000000   0.000000    85.710000
# 75%     29.500000    32.000000   3.500000   0.000000   100.000000
# max    208.000000   149.000000  19.000000   9.000000   139.600000

# %%
df_nz_1_bat.shape
# Out:
# (11, 7)

# %%
df_nz_1_bat.isnull().sum()
# Out:
# Player         0
# Dismissal      0
# Runs           0
# Balls Faced    0
# Fours          0
# Sixes          0
# Strike Rate    0
# dtype: int64

# %%
df_nz_1_bat
# Out:
#                Player             Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Rohit Sharma*  c Mitchell b Tickner    34           38      4      2
# 1        Shubman Gill  c Phillips b Shipley   208          149     19      9
# 2         Virat Kohli             b Santner     8           10      1      0
# 3       Ishan Kishan   c  Latham b Ferguson     5           14      0      0
# 4    Suryakumar Yadav  c Santner b Mitchell    31           26      4      0
# 5       Hardik Pandya            b Mitchell    28           38      3      0
# 6   Washington Sundar         lbw b Shipley    12           14      0      0
# 7      Shardul Thakur               run out     3            3      0      0
# 8       Kuldeep Yadav               not out     5            6      0      0
# 9      Mohammed Shami               not out     2            2      0      0
# 10     Mohammed Siraj                     -     0            0      0      0
#
#     Strike Rate
# 0         89.47
# ...

# %%
print(df_nz_1_bat.dtypes)
# Out:
# Player          object
# Dismissal       object
# Runs             int64
# Balls Faced      int64
# Fours            int64
# Sixes            int64
# Strike Rate    float64
# dtype: object

# %%
df_nz_1_bat
# Out:
#                Player             Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Rohit Sharma*  c Mitchell b Tickner    34           38      4      2
# 1        Shubman Gill  c Phillips b Shipley   208          149     19      9
# 2         Virat Kohli             b Santner     8           10      1      0
# 3       Ishan Kishan   c  Latham b Ferguson     5           14      0      0
# 4    Suryakumar Yadav  c Santner b Mitchell    31           26      4      0
# 5       Hardik Pandya            b Mitchell    28           38      3      0
# 6   Washington Sundar         lbw b Shipley    12           14      0      0
# 7      Shardul Thakur               run out     3            3      0      0
# 8       Kuldeep Yadav               not out     5            6      0      0
# 9      Mohammed Shami               not out     2            2      0      0
# 10     Mohammed Siraj                     -     0            0      0      0
#
#     Strike Rate
# 0         89.47
# ...

# %%
df_nz_3_bat
# Out:
#                Player             Dismissal   Runs  Balls Faced Fours Sixes  \
# 0      Rohit Sharma *           b Bracewell  101.0         85.0     9     6
# 1        Shubman Gill    c Conway b Tickner  112.0         78.0    13  LO 5
# 2         Virat Kohli       c Allen b Duffy   36.0         27.0     3     1
# 3       Ishan Kishant               run out   17.0         24.0     1     1
# 4    Suryakumar Yadav      c Conway b Duffy   14.0          9.0     O     2
# 5       Hardik Pandya      c Conway b Duffy   54.0         38.0     3     3
# 6   Washington Sundar  c Mitchell b Tickner    9.0         14.0     1     0
# 7      Shardul Thakur   c tLatham b Tickner   25.0         17.0     3     1
# 8       Kuldeep Yadav               run out    3.0          3.0     0     0
# 9         Umran Malik               not out    2.0          5.0     0     0
# 10   Yuzvendra Chahal                   NaN    NaN          NaN   NaN   NaN
#
#     Strike Rate
# 0        118.82
# 1        143.59
# ...

# %%
df_nz_3_bat.describe()
# Out:
#              Runs  Balls Faced  Strike Rate
# count   10.000000        10.00    10.000000
# mean    37.300000        30.00   111.559000
# std     39.788468        29.17    40.592784
# min      2.000000         3.00    40.000000
# 25%     10.250000        10.25    78.122500
# 50%     21.000000        20.50   126.075000
# 75%     49.500000        35.25   143.220000
# max    112.000000        85.00   155.560000

# %%
df_nz_3_bat.shape
# Out:
# (11, 7)

# %%
df_nz_3_bat.dtypes
# Out:
# Player          object
# Dismissal       object
# Runs           float64
# Balls Faced    float64
# Fours           object
# Sixes           object
# Strike Rate    float64
# dtype: object

# %%
df_nz_3_bat.isnull().sum()
# Out:
# Player         0
# Dismissal      0
# Runs           0
# Balls Faced    1
# Fours          1
# Sixes          1
# Strike Rate    1
# dtype: int64

# %%
df_nz_3_bat['Dismissal'] = df_nz_3_bat['Dismissal'].fillna('-')
df_nz_3_bat['Runs'] = df_nz_3_bat['Runs'].fillna(0)
df_nz_3_bat['Runs'] = df_nz_3_bat['Fours'].fillna(0)
df_nz_3_bat['Sixes'] = df_nz_3_bat['Sixes'].fillna(0)
df_nz_3_bat['Strike Rate'] = df_nz_3_bat['Strike Rate'].fillna(0)
df_nz_3_bat['Balls Faced'] = df_nz_3_bat['Balls Faced'].fillna(0)
df_nz_3_bat
# Out:
#                Player             Dismissal Runs  Balls Faced Fours Sixes  \
# 0      Rohit Sharma *           b Bracewell    9         85.0     9     6
# 1        Shubman Gill    c Conway b Tickner   13         78.0    13  LO 5
# 2         Virat Kohli       c Allen b Duffy    3         27.0     3     1
# 3       Ishan Kishant               run out    1         24.0     1     1
# 4    Suryakumar Yadav      c Conway b Duffy    O          9.0     O     2
# 5       Hardik Pandya      c Conway b Duffy    3         38.0     3     3
# 6   Washington Sundar  c Mitchell b Tickner    1         14.0     1     0
# 7      Shardul Thakur   c tLatham b Tickner    3         17.0     3     1
# 8       Kuldeep Yadav               run out    0          3.0     0     0
# 9         Umran Malik               not out    0          5.0     0     0
# 10   Yuzvendra Chahal                     -    0          0.0   NaN     0
#
#     Strike Rate
# 0        118.82
# 1        143.59
# 2        133.33
# ...

# %%
df_nz_3_bat.isnull().sum()
# Out:
# Player         0
# Dismissal      0
# Runs           0
# Balls Faced    0
# Fours          1
# Sixes          0
# Strike Rate    0
# dtype: int64

# %%
df_nz_3_bat['Fours'] = df_nz_3_bat['Fours'].fillna(0)
df_nz_3_bat
# Out:
#                Player             Dismissal Runs  Balls Faced Fours Sixes  \
# 0      Rohit Sharma *           b Bracewell    9         85.0     9     6
# 1        Shubman Gill    c Conway b Tickner   13         78.0    13  LO 5
# 2         Virat Kohli       c Allen b Duffy    3         27.0     3     1
# 3       Ishan Kishant               run out    1         24.0     1     1
# 4    Suryakumar Yadav      c Conway b Duffy    O          9.0     O     2
# 5       Hardik Pandya      c Conway b Duffy    3         38.0     3     3
# 6   Washington Sundar  c Mitchell b Tickner    1         14.0     1     0
# 7      Shardul Thakur   c tLatham b Tickner    3         17.0     3     1
# 8       Kuldeep Yadav               run out    0          3.0     0     0
# 9         Umran Malik               not out    0          5.0     0     0
# 10   Yuzvendra Chahal                     -    0          0.0     0     0
#
#     Strike Rate
# 0        118.82
# 1        143.59
# 2        133.33
# ...

# %%
df_nz_3_bat['Sixes'] = df_nz_3_bat['Sixes'].str.replace('[^0-9]', '', regex=True)
df_nz_3_bat
# Out:
#                Player             Dismissal Runs  Balls Faced Fours Sixes  \
# 0      Rohit Sharma *           b Bracewell    9         85.0     9     6
# 1        Shubman Gill    c Conway b Tickner   13         78.0    13     5
# 2         Virat Kohli       c Allen b Duffy    3         27.0     3     1
# 3       Ishan Kishant               run out    1         24.0     1     1
# 4    Suryakumar Yadav      c Conway b Duffy    O          9.0     O     2
# 5       Hardik Pandya      c Conway b Duffy    3         38.0     3     3
# 6   Washington Sundar  c Mitchell b Tickner    1         14.0     1     0
# 7      Shardul Thakur   c tLatham b Tickner    3         17.0     3     1
# 8       Kuldeep Yadav               run out    0          3.0     0     0
# 9         Umran Malik               not out    0          5.0     0     0
# 10   Yuzvendra Chahal                     -    0          0.0     0   NaN
#
#     Strike Rate
# 0        118.82
# 1        143.59
# 2        133.33
# ...

# %%
df_nz_3_bat['Sixes'] = df_nz_3_bat['Sixes'].fillna(0).astype(int)
df_nz_3_bat
# Out:
#                Player             Dismissal Runs  Balls Faced Fours  Sixes  \
# 0      Rohit Sharma *           b Bracewell    9         85.0     9      6
# 1        Shubman Gill    c Conway b Tickner   13         78.0    13      5
# 2         Virat Kohli       c Allen b Duffy    3         27.0     3      1
# 3       Ishan Kishant               run out    1         24.0     1      1
# 4    Suryakumar Yadav      c Conway b Duffy    O          9.0     O      2
# 5       Hardik Pandya      c Conway b Duffy    3         38.0     3      3
# 6   Washington Sundar  c Mitchell b Tickner    1         14.0     1      0
# 7      Shardul Thakur   c tLatham b Tickner    3         17.0     3      1
# 8       Kuldeep Yadav               run out    0          3.0     0      0
# 9         Umran Malik               not out    0          5.0     0      0
# 10   Yuzvendra Chahal                     -    0          0.0     0      0
#
#     Strike Rate
# 0        118.82
# 1        143.59
# ...

# %%
df_nz_3_bat.dtypes
# Out:
# Player          object
# Dismissal       object
# Runs            object
# Balls Faced    float64
# Fours           object
# Sixes            int32
# Strike Rate    float64
# dtype: object

# %%
df_as_1_bat
# Out:
#                 Player                          Dismissal  Runs  Balls Faced  \
# 0          Travis Head                  b  Mohammed Siraj   5.0         10.0
# 1       Mitchell Marsh        c  Mohammed Siraj b  Jadeja  81.0         65.0
# 2          Steve Smith                 c †Rahul b  Pandya  22.0         30.0
# 3   Marnus Labuschagne         c  Jadeja b  Kuldeep Yadav  15.0         22.0
# 4          Josh Inglis                  b  Mohammed Shami  26.0         27.0
# 5        Cameron Green                  b  Mohammed Shami  12.0         19.0
# 6        Glenn Maxwell                c  Pandya b  Jadeja   8.0         10.0
# 7       Marcus Stoinis  c  Shubman Gill b  Mohammed Shami   5.0          8.0
# 8          Sean Abbott  c  Shubman Gill b  Mohammed Siraj   0.0          7.0
# 9       Mitchell Starc                            not out   4.0         10.0
# 10          Adam Zampa         c †Rahul b  Mohammed Siraj   0.0          6.0
# ...

# %%
df_as_1_bat = df_as_1_bat.drop(index=range(10,11))
df_as_1_bat
# Out:
#               Player                Dismissal  Runs  Balls Faced  Fours  \
# 11      Ishan Kishan           lbw b  Stoinis   3.0          8.0    0.0
# 12      Shubman Gill  c  Labuschagne b  Starc  20.0         31.0    3.0
# 13       Virat Kohli             lbw b  Starc   4.0          9.0    1.0
# 14  Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 15          KL Rahul                  not out  75.0         91.0    7.0
# 16     Hardik Pandya      c  Green b  Stoinis  25.0         31.0    3.0
# 17   Ravindra Jadeja                  not out  45.0         69.0    5.0
# 18    Shardul Thakur                      NaN   NaN          NaN    NaN
# 19     Kuldeep Yadav                      NaN   NaN          NaN    NaN
# 20    Mohammed Siraj                      NaN   NaN          NaN    NaN
# 21    Mohammed Shami                      NaN   NaN          NaN    NaN
#
#     Sixes  Strike Rate
# 11    0.0        37.50
# 12    0.0        64.52
# 13    0.0        44.44
# ...

# %%
df_as_1_bat = df_as_1_bat.reset_index(drop=True)
df_as_1_bat
# Out:
#               Player                Dismissal  Runs  Balls Faced  Fours  \
# 0       Ishan Kishan           lbw b  Stoinis   3.0          8.0    0.0
# 1       Shubman Gill  c  Labuschagne b  Starc  20.0         31.0    3.0
# 2        Virat Kohli             lbw b  Starc   4.0          9.0    1.0
# 3   Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 4           KL Rahul                  not out  75.0         91.0    7.0
# 5      Hardik Pandya      c  Green b  Stoinis  25.0         31.0    3.0
# 6    Ravindra Jadeja                  not out  45.0         69.0    5.0
# 7     Shardul Thakur                      NaN   NaN          NaN    NaN
# 8      Kuldeep Yadav                      NaN   NaN          NaN    NaN
# 9     Mohammed Siraj                      NaN   NaN          NaN    NaN
# 10    Mohammed Shami                      NaN   NaN          NaN    NaN
#
#     Sixes  Strike Rate
# 0     0.0        37.50
# 1     0.0        64.52
# 2     0.0        44.44
# ...

# %%
df_as_1_bat.describe()
# Out:
#             Runs  Balls Faced     Fours     Sixes  Strike Rate
# count   7.000000     7.000000  7.000000  7.000000     7.000000
# mean   24.571429    34.285714  2.714286  0.285714    53.535714
# std    27.306026    33.865982  2.627691  0.487950    28.961504
# min     0.000000     1.000000  0.000000  0.000000     0.000000
# 25%     3.500000     8.500000  0.500000  0.000000    40.970000
# 50%    20.000000    31.000000  3.000000  0.000000    64.520000
# 75%    35.000000    50.000000  4.000000  0.500000    72.935000
# max    75.000000    91.000000  7.000000  1.000000    82.420000

# %%
df_as_1_bat.isnull().sum()
# Out:
# Player         0
# Dismissal      4
# Runs           4
# Balls Faced    4
# Fours          4
# Sixes          4
# Strike Rate    4
# dtype: int64

# %%
df_as_1_bat['Dismissal'] = df_as_1_bat['Dismissal'].fillna('-')
df_as_1_bat['Runs'] = df_as_1_bat['Runs'].fillna(0)
df_as_1_bat['Balls Faced'] = df_as_1_bat['Balls Faced'].fillna(0)
df_as_1_bat['Fours'] = df_as_1_bat['Fours'].fillna(0)
df_as_1_bat['Sixes'] = df_as_1_bat['Sixes'].fillna(0)
df_as_1_bat['Strike Rate'] = df_as_1_bat['Strike Rate'].fillna(0)
df_as_1_bat
# Out:
#               Player                Dismissal  Runs  Balls Faced  Fours  \
# 0       Ishan Kishan           lbw b  Stoinis   3.0          8.0    0.0
# 1       Shubman Gill  c  Labuschagne b  Starc  20.0         31.0    3.0
# 2        Virat Kohli             lbw b  Starc   4.0          9.0    1.0
# 3   Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 4           KL Rahul                  not out  75.0         91.0    7.0
# 5      Hardik Pandya      c  Green b  Stoinis  25.0         31.0    3.0
# 6    Ravindra Jadeja                  not out  45.0         69.0    5.0
# 7     Shardul Thakur                        -   0.0          0.0    0.0
# 8      Kuldeep Yadav                        -   0.0          0.0    0.0
# 9     Mohammed Siraj                        -   0.0          0.0    0.0
# 10    Mohammed Shami                        -   0.0          0.0    0.0
#
#     Sixes  Strike Rate
# 0     0.0        37.50
# 1     0.0        64.52
# 2     0.0        44.44
# ...

# %%
df_as_2_bat
# Out:
#                 Player                Dismissal  Runs  Balls Faced  Fours  \
# 0         Rohit Sharma        c  Smith b  Starc  13.0         15.0    2.0
# 1         Shubman Gill  c  Labuschagne b  Starc   0.0          2.0    0.0
# 2          Virat Kohli             lbw b  Ellis  31.0         35.0    4.0
# 3     Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 4             KL Rahul             lbw b  Starc   9.0         12.0    1.0
# 5        Hardik Pandya       c  Smith b  Abbott   1.0          3.0    0.0
# 6      Ravindra Jadeja        c †Carey b  Ellis  16.0         39.0    1.0
# 7           Axar Patel                  not out  29.0         29.0    1.0
# 8        Kuldeep Yadav        c  Head b  Abbott   4.0         17.0    0.0
# 9       Mohammed Shami       c †Carey b  Abbott   0.0          1.0    0.0
# 10      Mohammed Siraj                 b  Starc   0.0          3.0    0.0
# 11         Travis Head                  not out  51.0         30.0   10.0
# ...

# %%
df_as_2_bat = df_as_2_bat.drop(index=range(11,2b0))
df_as_2_bat
# Out:
#               Player                Dismissal  Runs  Balls Faced  Fours  \
# 0       Rohit Sharma        c  Smith b  Starc  13.0         15.0    2.0
# 1       Shubman Gill  c  Labuschagne b  Starc   0.0          2.0    0.0
# 2        Virat Kohli             lbw b  Ellis  31.0         35.0    4.0
# 3   Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 4           KL Rahul             lbw b  Starc   9.0         12.0    1.0
# 5      Hardik Pandya       c  Smith b  Abbott   1.0          3.0    0.0
# 6    Ravindra Jadeja        c †Carey b  Ellis  16.0         39.0    1.0
# 7         Axar Patel                  not out  29.0         29.0    1.0
# 8      Kuldeep Yadav        c  Head b  Abbott   4.0         17.0    0.0
# 9     Mohammed Shami       c †Carey b  Abbott   0.0          1.0    0.0
# 10    Mohammed Siraj                 b  Starc   0.0          3.0    0.0
# 20        Adam Zampa                      NaN   NaN          NaN    NaN
# ...

# %%
df_as_2_bat = df_as_2_bat.drop(index=range(21,22))
df_as_2_bat
# Out:
#               Player                Dismissal  Runs  Balls Faced  Fours  \
# 0       Rohit Sharma        c  Smith b  Starc  13.0         15.0    2.0
# 1       Shubman Gill  c  Labuschagne b  Starc   0.0          2.0    0.0
# 2        Virat Kohli             lbw b  Ellis  31.0         35.0    4.0
# 3   Suryakumar Yadav             lbw b  Starc   0.0          1.0    0.0
# 4           KL Rahul             lbw b  Starc   9.0         12.0    1.0
# 5      Hardik Pandya       c  Smith b  Abbott   1.0          3.0    0.0
# 6    Ravindra Jadeja        c †Carey b  Ellis  16.0         39.0    1.0
# 7         Axar Patel                  not out  29.0         29.0    1.0
# 8      Kuldeep Yadav        c  Head b  Abbott   4.0         17.0    0.0
# 9     Mohammed Shami       c †Carey b  Abbott   0.0          1.0    0.0
# 10    Mohammed Siraj                 b  Starc   0.0          3.0    0.0
#
#     Sixes  Strike Rate
# 0     0.0        86.67
# 1     0.0         0.00
# 2     0.0        88.57
# ...

# %%
df_as_2_bat.describe()
# Out:
#             Runs  Balls Faced      Fours      Sixes  Strike Rate
# count  11.000000    11.000000  11.000000  11.000000    11.000000
# mean    9.363636    14.272727   0.818182   0.181818    40.739091
# std    11.664242    14.241425   1.250454   0.603023    40.091066
# min     0.000000     1.000000   0.000000   0.000000     0.000000
# 25%     0.000000     2.500000   0.000000   0.000000     0.000000
# 50%     4.000000    12.000000   0.000000   0.000000    33.330000
# 75%    14.500000    23.000000   1.000000   0.000000    80.835000
# max    31.000000    39.000000   4.000000   2.000000   100.000000

# %%
df_as_2_bat.isnull().sum()
# Out:
# Player         0
# Dismissal      0
# Runs           0
# Balls Faced    0
# Fours          0
# Sixes          0
# Strike Rate    0
# dtype: int64

# %%
df_as_3_bat
# Out:
#                 Player                         Dismissal  Runs  Balls Faced  \
# 0          Travis Head        c  Kuldeep Yadav b  Pandya    33           31
# 1       Mitchell Marsh                         b  Pandya    47           47
# 2          Steve Smith                c †Rahul b  Pandya     0            3
# 3         David Warner        c  Pandya b  Kuldeep Yadav    23           31
# 4   Marnus Labuschagne  c  Shubman Gill b  Kuldeep Yadav    28           45
# 5           Alex Carey                  b  Kuldeep Yadav    38           46
# 6       Marcus Stoinis          c  Shubman Gill b  Patel    25           26
# 7          Sean Abbott                          b  Patel    26           23
# 8          Ashton Agar        c  Patel b  Mohammed Siraj    17           21
# 9       Mitchell Starc       c  Jadeja b  Mohammed Siraj    10           11
# 10          Adam Zampa                           not out    10           11
# ...

# %%
df_as_3_bat = df_as_3_bat.drop(index = range(0,10))
df_as_3_bat
# Out:
#               Player            Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 10        Adam Zampa              not out    10           11      1      0
# 11      Rohit Sharma   c  Starc b  Abbott    30           17      2      2
# 12      Shubman Gill         lbw b  Zampa    37           49      4      1
# 13       Virat Kohli    c  Warner b  Agar    54           72      2      1
# 14          KL Rahul   c  Abbott b  Zampa    32           50      2      1
# 15        Axar Patel              run out     2            4      0      0
# 16     Hardik Pandya    c  Smith b  Zampa    40           40      3      1
# 17  Suryakumar Yadav              b  Agar     0            1      0      0
# 18   Ravindra Jadeja  c  Stoinis b  Zampa    18           33      1      0
# 19     Kuldeep Yadav              run out     6           15      0      0
# 20    Mohammed Shami           b  Stoinis    14           10      1      1
# ...

# %%
df_as_3_bat = df_as_3_bat.drop(index = 10)
df_as_3_bat
# Out:
#               Player            Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 11      Rohit Sharma   c  Starc b  Abbott    30           17      2      2
# 12      Shubman Gill         lbw b  Zampa    37           49      4      1
# 13       Virat Kohli    c  Warner b  Agar    54           72      2      1
# 14          KL Rahul   c  Abbott b  Zampa    32           50      2      1
# 15        Axar Patel              run out     2            4      0      0
# 16     Hardik Pandya    c  Smith b  Zampa    40           40      3      1
# 17  Suryakumar Yadav              b  Agar     0            1      0      0
# 18   Ravindra Jadeja  c  Stoinis b  Zampa    18           33      1      0
# 19     Kuldeep Yadav              run out     6           15      0      0
# 20    Mohammed Shami           b  Stoinis    14           10      1      1
# 21    Mohammed Siraj              not out     3            5      0      0
#
#     Strike Rate
# 11       176.47
# 12        75.51
# ...

# %%
df_as_3_bat = df_as_3_bat.reset_index(drop=True)
df_as_3_bat
# Out:
#               Player            Dismissal  Runs  Balls Faced  Fours  Sixes  \
# 0       Rohit Sharma   c  Starc b  Abbott    30           17      2      2
# 1       Shubman Gill         lbw b  Zampa    37           49      4      1
# 2        Virat Kohli    c  Warner b  Agar    54           72      2      1
# 3           KL Rahul   c  Abbott b  Zampa    32           50      2      1
# 4         Axar Patel              run out     2            4      0      0
# 5      Hardik Pandya    c  Smith b  Zampa    40           40      3      1
# 6   Suryakumar Yadav              b  Agar     0            1      0      0
# 7    Ravindra Jadeja  c  Stoinis b  Zampa    18           33      1      0
# 8      Kuldeep Yadav              run out     6           15      0      0
# 9     Mohammed Shami           b  Stoinis    14           10      1      1
# 10    Mohammed Siraj              not out     3            5      0      0
#
#     Strike Rate
# 0        176.47
# 1         75.51
# ...

# %%
df_as_1_bowl
# Out:
#       Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0   Mohammed Shami            6.0                     2            17
# 1   Mohammed Siraj            5.4                     1            29
# 2    Hardik Pandya            5.0                     0            29
# 3   Shardul Thakur            2.0                     0            12
# 4  Ravindra Jadeja            9.0                     0            46
# 5    Kuldeep Yadav            8.0                     1            48
#
#    Players_Wickets  Players_Economic_rate
# 0                3                   2.83
# 1                3                   5.12
# 2                1                   5.80
# 3                0                   6.00
# 4                2                   5.11
# 5                1                   6.00

# %%
df_as_1_bowl.isnull().sum()
# Out:
# Players_name             0
# Players_overs            0
# Players_Maiden_overs     0
# Players_Runs             0
# Players_Wickets          0
# Players_Economic_rate    0
# dtype: int64

# %%
df_as_2_bowl
# Out:
#      players_name  players_overs  players_maidens_over  players_Runs  \
# 0  Mohammed Shami            3.0                     0            29
# 1  Mohammed Siraj            3.0                     0            37
# 2      Axar Patel            3.0                     0            25
# 3   Hardik Pandya            1.0                     0            18
# 4   Kuldeep Yadav            1.0                     0            12
#
#    players_wickets  players_Economic_rate
# 0                0                   9.67
# 1                0                  12.33
# 2                0                   8.33
# 3                0                  18.00
# 4                0                  12.00

# %%
df_as_2_bowl.isnull().sum()
# Out:
# players_name             0
# players_overs            0
# players_maidens_over     0
# players_Runs             0
# players_wickets          0
# players_Economic_rate    0
# dtype: int64

# %%
df_as_3_bowl
# Out:
#   player_name_name  player_name_Overs  player_name_maiden_over  \
# 0   Mohammed Shami                6.0                        0
# 1   Mohammed Siraj                7.0                        1
# 2       Axar Patel                8.0                        0
# 3    Hardik Pandya                8.0                        0
# 4  Ravindra Jadeja               10.0                        0
# 5    Kuldeep Yadav               10.0                        1
#
#    player_name_runs  player_name_wickets  player_name_Economic_rate
# 0                37                    0                       6.17
# 1                37                    2                       5.29
# 2                57                    2                       7.13
# 3                44                    3                       5.50
# 4                34                    0                       3.40
# 5                56                    3                       5.60

# %%
df_as_3_bowl.isnull().sum()
# Out:
# player_name_name             0
# player_name_Overs            0
# player_name_maiden_over      0
# player_name_runs             0
# player_name_wickets          0
# player_name_Economic_rate    0
# dtype: int64

# %%
df_nz_1_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0     Mohammed Shami           10.0                     1            69
# 1     Mohammed Siraj           10.0                     2            46
# 2      Hardik Pandya            7.0                     0            70
# 3      Kuldeep Yadav            8.0                     1            43
# 4     Shardul Thakur            7.2                     0            54
# 5  Washington Sundar            7.0                     0            50
#
#    Players_Wickets  Players_Economic_rate
# 0                1                   6.90
# 1                4                   4.60
# 2                1                  10.00
# 3                2                   5.38
# 4                2                   7.36
# 5                0                   7.14

# %%
df_nz_1_bowl.isnull().sum()
# Out:
# Players_name             0
# Players_overs            0
# Players_Maiden_overs     0
# Players_Runs             0
# Players_Wickets          0
# Players_Economic_rate    0
# dtype: int64

# %%
df_nz_2_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0     Mohammed Shami            6.0                   1.0          18.0
# 1     Mohammed Siraj            6.0                   1.0          10.0
# 2     Shardul Thakur            6.0                   1.0          26.0
# 3      Hardik Pandya            6.0                   3.0          16.0
# 4      Kuldeep Yadav            7.3                   0.0          29.0
# 5  Washington Sundar            3.0                   1.0           7.0
# 6                NaN            NaN                   NaN           NaN
#
#    Players_Wickets  Players_Economic_rate  Unnamed: 6
# 0              3.0                   3.00         NaN
# 1              1.0                   1.67         NaN
# 2              1.0                   4.33         NaN
# 3              2.0                   2.67         NaN
# 4              1.0                   3.87         NaN
# 5              2.0                   2.33         NaN
# ...

# %%
df_nz_2_bowl.dtypes
# Out:
# Players_name              object
# Players_overs            float64
# Players_Maiden_overs     float64
# Players_Runs             float64
# Players_Wickets          float64
# Players_Economic_rate    float64
# Unnamed: 6               float64
# dtype: object

# %%
df_nz_2_bowl.drop(index=6, inplace=True)  # Remove row with index label 3
df_nz_2_bowl.drop('Unnamed: 6', axis=1, inplace=True)  # Remove column with name 'column_name'
df_nz_2_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0     Mohammed Shami            6.0                   1.0          18.0
# 1     Mohammed Siraj            6.0                   1.0          10.0
# 2     Shardul Thakur            6.0                   1.0          26.0
# 4      Kuldeep Yadav            7.3                   0.0          29.0
# 5  Washington Sundar            3.0                   1.0           7.0
#
#    Players_Wickets  Players_Economic_rate
# 0              3.0                   3.00
# 1              1.0                   1.67
# 2              1.0                   4.33
# 4              1.0                   3.87
# 5              2.0                   2.33

# %%
df_nz_2_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0     Mohammed Shami            6.0                   1.0          18.0
# 1     Mohammed Siraj            6.0                   1.0          10.0
# 2     Shardul Thakur            6.0                   1.0          26.0
# 4      Kuldeep Yadav            7.3                   0.0          29.0
# 5  Washington Sundar            3.0                   1.0           7.0
#
#    Players_Wickets  Players_Economic_rate
# 0              3.0                   3.00
# 1              1.0                   1.67
# 2              1.0                   4.33
# 4              1.0                   3.87
# 5              2.0                   2.33

# %%
df_nz_3_bowl
# Out:
#          Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0       Hardik Pandya            6.0                     0            37
# 1   Washington Sundar            6.0                     0            49
# 2      Shardul Thakur            6.0                     0            45
# 3       Umran Malik\n            7.0                     0            52
# 4       Kuldeep Yadav            9.0                     0            62
# 5  Yuzvendra Chahal\n            7.2                     0            43
#
#    Players_Wickets  Players_Economic_rate
# 0                1                   6.17
# 1                0                   8.17
# 2                3                   7.50
# 3                1                   7.43
# 4                3                   6.89
# 5                2                   5.86

# %%
df_sa_1_bowl
# Out:
#                                         Players_name  Players_overs  \
# 0                                     Mohammed Siraj              8
# 1                                         Avesh Khan              8
# 2                                     Shardul Thakur              8
# 3  Ravi Bishnoi\nâ€’â€’â€’â€’â€’â€’â€’â€’â€’â€’â€...              8
# 4                                      Kuldeep Yadav              8
#
#    Players_Maiden_overs Players_Runs  Players_Wickets  Players_Economic_rate
# 0                     0           49                0                   6.13
# 1                     0           51                0                   6.38
# 2                     1           35                2                   4.38
# 3                     0           69                1                   8.63
# 4                     0        39 49                1                   4.88

# %%
df_sa_1_bowl['Players_name'] = df_sa_1_bowl['Players_name'].str.replace('\u20AC', '')

df_sa_1_bowl['Players_name'] = df_sa_1_bowl['Players_name'].str.replace('[^\x00-\x7F]', '')

df_sa_1_bowl['Players_Runs'] = df_sa_1_bowl['Players_Runs'].str.replace('39', '')
df_sa_1_bowl['Players_name'] = df_sa_1_bowl['Players_name'].str.replace('\n', '')
df_sa_1_bowl
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_1524\2358891413.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_sa_1_bowl['Players_name'] = df_sa_1_bowl['Players_name'].str.replace('[^\x00-\x7F]', '')
#      Players_name  Players_overs  Players_Maiden_overs Players_Runs  \
# 0  Mohammed Siraj              8                     0           49
# 1      Avesh Khan              8                     0           51
# 2  Shardul Thakur              8                     1           35
# 3    Ravi Bishnoi              8                     0           69
# 4   Kuldeep Yadav              8                     0           49
#
#    Players_Wickets  Players_Economic_rate
# 0                0                   6.13
# 1                0                   6.38
# 2                2                   4.38
# 3                1                   8.63
# 4                1                   4.88

# %%
df_sa_1_bowl.describe()
# Out:
#        Players_overs  Players_Maiden_overs  Players_Wickets  \
# count            5.0              5.000000          5.00000
# mean             8.0              0.200000          0.80000
# std              0.0              0.447214          0.83666
# min              8.0              0.000000          0.00000
# 25%              8.0              0.000000          0.00000
# 50%              8.0              0.000000          1.00000
# 75%              8.0              0.000000          1.00000
# max              8.0              1.000000          2.00000
#
#        Players_Economic_rate
# count               5.000000
# mean                6.080000
# std                 1.652649
# min                 4.380000
# 25%                 4.880000
# 50%                 6.130000
# 75%                 6.380000
# max                 8.630000

# %%
df_sa_1_bowl.isnull().sum()
# Out:
# Players_name             0
# Players_overs            0
# Players_Maiden_overs     0
# Players_Runs             0
# Players_Wickets          0
# Players_Economic_rate    0
# dtype: int64

# %%
df_sa_2_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0     Mohammed Siraj             10                     1            38
# 1  Washington Sundar              9                     0            60
# 2      Shahbaz Ahmed             10                     0            54
# 3         Avesh Khan              7                     0            35
# 4      Kuldeep Yadav              9                     0            49
# 5     Shardul Thakur              5                     0            36
#
#    Players_Wickets  Players_Economic_rate
# 0                3                   3.80
# 1                1                   6.67
# 2                1                   5.40
# 3                0                   5.00
# 4                1                   5.44
# 5                1                   7.20

# %%
df_sa_2_bowl.isnull().sum()
# Out:
# Players_name             0
# Players_overs            0
# Players_Maiden_overs     0
# Players_Runs             0
# Players_Wickets          0
# Players_Economic_rate    0
# dtype: int64

# %%
df_sa_2_bowl.describe()
# Out:
#        Players_overs  Players_Maiden_overs  Players_Runs  Players_Wickets  \
# count       6.000000              6.000000      6.000000         6.000000
# mean        8.333333              0.166667     45.333333         1.166667
# std         1.966384              0.408248     10.500794         0.983192
# min         5.000000              0.000000     35.000000         0.000000
# 25%         7.500000              0.000000     36.500000         1.000000
# 50%         9.000000              0.000000     43.500000         1.000000
# 75%         9.750000              0.000000     52.750000         1.000000
# max        10.000000              1.000000     60.000000         3.000000
#
#        Players_Economic_rate
# count               6.000000
# mean                5.585000
# std                 1.214014
# min                 3.800000
# 25%                 5.100000
# 50%                 5.420000
# 75%                 6.362500
# max                 7.200000

# %%
df_sa_3_bowl
# Out:
#         Players_name  Players_overs  Players_Maiden_overs  Players_Runs  \
# 0  Washington Sundar            4.0                     0            15
# 1     Mohammed Siraj            5.0                     0            17
# 2         Avesh Khan            5.0                     1             8
# 3      Shahbaz Ahmed            7.0                     0            32
# 4     Shardul Thakur            2.0                     0             8
# 5      Kuldeep Yadav            4.1                     1            18
#
#    Players_Wickets  Players_Economic_rate
# 0                2                   3.75
# 1                2                   3.40
# 2                0                   1.60
# 3                2                   4.57
# 4                0                   4.00
# 5                4                   4.32

# %%
df_sa_3_bowl.describe()
# Out:
#        Players_overs  Players_Maiden_overs  Players_Runs  Players_Wickets  \
# count       6.000000              6.000000      6.000000         6.000000
# mean        4.516667              0.333333     16.333333         1.666667
# std         1.637580              0.516398      8.824209         1.505545
# min         2.000000              0.000000      8.000000         0.000000
# 25%         4.025000              0.000000      9.750000         0.500000
# 50%         4.550000              0.000000     16.000000         2.000000
# 75%         5.000000              0.750000     17.750000         2.000000
# max         7.000000              1.000000     32.000000         4.000000
#
#        Players_Economic_rate
# count               6.000000
# mean                3.606667
# std                 1.065977
# min                 1.600000
# 25%                 3.487500
# 50%                 3.875000
# 75%                 4.240000
# max                 4.570000

# %%
df_sa_3_bowl.isnull().sum()
# Out:
# Players_name             0
# Players_overs            0
# Players_Maiden_overs     0
# Players_Runs             0
# Players_Wickets          0
# Players_Economic_rate    0
# dtype: int64

# %%
df_nz_2_bat = pd.read_csv('Scorecard_bat_2_newz.csv',encoding='cp1252')

# %%
df_nz_2_bat = df_nz_2_bat.drop(index=range(11,65))
df_nz_2_bat
# Out:
#                 India               Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*           lbw b Shipley   51          50     7     2
# 1        Shubman Gill                 not out   40          53     6     0
# 2         Virat Kohli  st â€ Latham b Santner   11           9     2     0
# 3     Ishan Kishanâ€                  not out    8           9     2     0
# 4    Suryakumar Yadav                     NaN  NaN         NaN   NaN   NaN
# 5       Hardik Pandya                     NaN  NaN         NaN   NaN   NaN
# 6   Washington Sundar                     NaN  NaN         NaN   NaN   NaN
# 7      Shardul Thakur                     NaN  NaN         NaN   NaN   NaN
# 8       Kuldeep Yadav                     NaN  NaN         NaN   NaN   NaN
# 9      Mohammed Shami                     NaN  NaN         NaN   NaN   NaN
# 10     Mohammed Siraj                     NaN  NaN         NaN   NaN   NaN
#
#    Strike Rate Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
df_nz_2_bat.drop('Unnamed: 7', axis=1, inplace=True)
df_nz_2_bat.drop('Unnamed: 8', axis=1, inplace=True)
df_nz_2_bat.drop('Unnamed: 9', axis=1, inplace=True)
df_nz_2_bat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 df_nz_2_bat.drop('Unnamed: 7', axis=1, inplace=True)
#       2 df_nz_2_bat.drop('Unnamed: 8', axis=1, inplace=True)
#       3 df_nz_2_bat.drop('Unnamed: 9', axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df_nz_2_bat['Dismissal'] = df_nz_2_bat['Dismissal'].fillna('-')
df_nz_2_bat['Dismissal'] = df_nz_2_bat['Dismissal'].replace('0','-')
df_nz_2_bat['Runs'] = df_nz_2_bat['Runs'].fillna(0)
df_nz_2_bat['Fours'] = df_nz_2_bat['Fours'].fillna(0)
df_nz_2_bat['Sixes'] = df_nz_2_bat['Sixes'].fillna(0)
df_nz_2_bat['Strike Rate'] = df_nz_2_bat['Strike Rate'].fillna(0)
df_nz_2_bat['Balls Faced'] = df_nz_2_bat['Balls Faced'].fillna(0)
df_nz_2_bat
# Out:
#                 India               Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*           lbw b Shipley   51          50     7     2
# 1        Shubman Gill                 not out   40          53     6     0
# 2         Virat Kohli  st â€ Latham b Santner   11           9     2     0
# 3     Ishan Kishanâ€                  not out    8           9     2     0
# 4    Suryakumar Yadav                       0    0           0     0     0
# 5       Hardik Pandya                       0    0           0     0     0
# 6   Washington Sundar                       0    0           0     0     0
# 7      Shardul Thakur                       0    0           0     0     0
# 8       Kuldeep Yadav                       0    0           0     0     0
# 9      Mohammed Shami                       0    0           0     0     0
# 10     Mohammed Siraj                       0    0           0     0     0
#
#    Strike Rate
# 0          102
# 1        75.47
# 2       122.22
# ...

# %%
df_nz_2_bat['India'] = df_nz_2_bat['India'].str.replace('\u20AC', '')
df_nz_2_bat['Dismissal'] = df_nz_2_bat['Dismissal'].str.replace('\u20AC', '')
df_nz_2_bat
# Out:
#                 India              Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*          lbw b Shipley   51          50     7     2
# 1        Shubman Gill                not out   40          53     6     0
# 2         Virat Kohli  st â Latham b Santner   11           9     2     0
# 3      Ishan Kishanâ                 not out    8           9     2     0
# 4    Suryakumar Yadav                    NaN    0           0     0     0
# 5       Hardik Pandya                    NaN    0           0     0     0
# 6   Washington Sundar                    NaN    0           0     0     0
# 7      Shardul Thakur                    NaN    0           0     0     0
# 8       Kuldeep Yadav                    NaN    0           0     0     0
# 9      Mohammed Shami                    NaN    0           0     0     0
# 10     Mohammed Siraj                    NaN    0           0     0     0
#
#    Strike Rate
# 0          102
# 1        75.47
# 2       122.22
# ...

# %%
df_nz_2_bat['India'] = df_nz_2_bat['India'].str.replace('â', '')
df_nz_2_bat['Dismissal'] = df_nz_2_bat['Dismissal'].str.replace('â', '')
df_nz_2_bat
# Out:
#                 India             Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*         lbw b Shipley   51          50     7     2
# 1        Shubman Gill               not out   40          53     6     0
# 2         Virat Kohli  st  Latham b Santner   11           9     2     0
# 3       Ishan Kishan                not out    8           9     2     0
# 4    Suryakumar Yadav                   NaN    0           0     0     0
# 5       Hardik Pandya                   NaN    0           0     0     0
# 6   Washington Sundar                   NaN    0           0     0     0
# 7      Shardul Thakur                   NaN    0           0     0     0
# 8       Kuldeep Yadav                   NaN    0           0     0     0
# 9      Mohammed Shami                   NaN    0           0     0     0
# 10     Mohammed Siraj                   NaN    0           0     0     0
#
#    Strike Rate
# 0          102
# 1        75.47
# 2       122.22
# 3        88.89
# ...

# %%
df_nz_2_bat['Dismissal'] = df_nz_2_bat['Dismissal'].fillna('-')
df_nz_2_bat
# Out:
#                 India             Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*         lbw b Shipley   51          50     7     2
# 1        Shubman Gill               not out   40          53     6     0
# 2         Virat Kohli  st  Latham b Santner   11           9     2     0
# 3       Ishan Kishan                not out    8           9     2     0
# 4    Suryakumar Yadav                     -    0           0     0     0
# 5       Hardik Pandya                     -    0           0     0     0
# 6   Washington Sundar                     -    0           0     0     0
# 7      Shardul Thakur                     -    0           0     0     0
# 8       Kuldeep Yadav                     -    0           0     0     0
# 9      Mohammed Shami                     -    0           0     0     0
# 10     Mohammed Siraj                     -    0           0     0     0
#
#    Strike Rate
# 0          102
# 1        75.47
# 2       122.22
# 3        88.89
# ...

# %%
new_column_names = ['Player', 'Dismissal', 'Runs', 'Balls Faced', 'Fours','Sixes', 'Strike Rate']  # List of new column names
df_nz_2_bat.columns = new_column_names
df_nz_1_bat.columns = new_column_names
df_nz_3_bat.columns = new_column_names
df_as_1_bat.columns = new_column_names
df_as_2_bat.columns = new_column_names
df_as_3_bat.columns = new_column_names
df_sa_1_bat.columns = new_column_names
df_sa_2_bat.columns = new_column_names
df_sa_3_bat.columns = new_column_names

# %%
df_nz_1_bowl
new_col = ['Player', 'Overs', 'Maiden', 'Runs', 'Wickets', 'Economy_rate']
df_nz_1_bowl.columns = new_col
df_nz_2_bowl.columns = new_col
df_nz_3_bowl.columns = new_col
df_as_1_bowl.columns = new_col
df_as_2_bowl.columns = new_col
df_as_3_bowl.columns = new_col
df_sa_1_bowl.columns = new_col
df_sa_2_bowl.columns = new_col
df_sa_3_bowl.columns = new_col

# %%
# Assuming you have loaded scorecards into separate DataFrames: df1, df2, df3, ...
combined_df = pd.concat([df_nz_1_bowl, df_nz_2_bowl], ignore_index=True)
combined_df
concatenated_df = pd.concat([combined_df,df_nz_3_bowl,df_as_1_bowl,df_as_2_bowl,df_as_3_bowl,df_sa_1_bowl,df_sa_2_bowl,df_sa_3_bowl], ignore_index = True)
concatenated_df
# Out:
#                 Player  Overs  Maiden  Runs  Wickets  Economy_rate
# 0       Mohammed Shami   10.0     1.0  69.0      1.0          6.90
# 1       Mohammed Siraj   10.0     2.0  46.0      4.0          4.60
# 2        Hardik Pandya    7.0     0.0  70.0      1.0         10.00
# 3        Kuldeep Yadav    8.0     1.0  43.0      2.0          5.38
# 4       Shardul Thakur    7.2     0.0  54.0      2.0          7.36
# 5    Washington Sundar    7.0     0.0  50.0      0.0          7.14
# 6       Mohammed Shami    6.0     1.0  18.0      3.0          3.00
# 7       Mohammed Siraj    6.0     1.0  10.0      1.0          1.67
# 8       Shardul Thakur    6.0     1.0  26.0      1.0          4.33
# 9        Kuldeep Yadav    7.3     0.0  29.0      1.0          3.87
# 10   Washington Sundar    3.0     1.0   7.0      2.0          2.33
# 11       Hardik Pandya    6.0     0.0    37      1.0          6.17
# 12   Washington Sundar    6.0     0.0    49      0.0          8.17
# ...

# %%
concatenated2_df = pd.concat([df_nz_1_bat, df_nz_2_bat,df_nz_3_bat,df_as_1_bat,df_as_2_bat,df_as_3_bat,df_sa_1_bat,df_sa_2_bat,df_sa_3_bat], ignore_index=True)
concatenated2_df
# Out:
#                Player               Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*    c Mitchell b Tickner   34          38     4     2
# 1        Shubman Gill    c Phillips b Shipley  208         149    19     9
# 2         Virat Kohli               b Santner    8          10     1     0
# 3     Ishan Kishanâ€   c â€ Latham b Ferguson    5          14     0     0
# 4    Suryakumar Yadav    c Santner b Mitchell   31          26     4     0
# ..                ...                     ...  ...         ...   ...   ...
# 92     Shardul Thakur                       -    0           0     0     0
# 93  Washington Sundar                       -    0           0     0     0
# 94      Shahbaz Ahmed                       -    0           0     0     0
# 95      Kuldeep Yadav                       -    0           0     0     0
# 96         Avesh Khan                       -    0           0     0     0
#
#    Strike Rate
# 0        89.47
# 1        139.6
# 2         80.0
# ...

# %%
concatenated2_df.tail()
# Out:
#                Player Dismissal Runs Balls Faced Fours Sixes Strike Rate
# 92     Shardul Thakur         -    0           0     0     0           0
# 93  Washington Sundar         -    0           0     0     0           0
# 94      Shahbaz Ahmed         -    0           0     0     0           0
# 95      Kuldeep Yadav         -    0           0     0     0           0
# 96         Avesh Khan         -    0           0     0     0           0

# %%
total_overs_by_bowler = concatenated_df.groupby('Player')['Overs'].sum().reset_index()
total_overs_by_bowler
# Out:
#                 Player  Overs
# 0           Avesh Khan   20.0
# 1           Axar Patel   11.0
# 2        Hardik Pandya   27.0
# 3        Kuldeep Yadav   64.4
# 4       Mohammed Shami   31.0
# 5       Mohammed Siraj   54.4
# 6         Ravi Bishnoi    8.0
# 7      Ravindra Jadeja   19.0
# 8        Shahbaz Ahmed   17.0
# 9       Shardul Thakur   36.2
# 10       Umran Malik\n    7.0
# 11   Washington Sundar   29.0
# 12  Yuzvendra Chahal\n    7.2

# %%
# Assuming you have a DataFrame named 'bowling_data' with columns: 'Bowler', 'Overs'
# Assuming you have a DataFrame named 'total_overs_by_bowler' with columns: 'Bowler', 'Total Overs'

# Merge the two DataFrames based on the 'Bowler' column
merged1_df = pd.merge(concatenated_df, total_overs_by_bowler, on='Player', how='left')

# The resulting DataFrame 'merged_df' will contain the original columns along with the 'Total Overs' column
merged1_df
# Out:
#                 Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y
# 0       Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1       Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2        Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3        Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4       Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5    Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6       Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7       Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8       Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9        Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10   Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df.drop_duplicates(subset='Player', inplace=True)
merged1_df.reset_index(drop=True, inplace=True)

# %%
merged1_df
# Out:
#                 Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y
# 0       Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1       Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2        Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3        Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4       Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5    Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6       Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7       Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8       Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9        Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10   Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df['Player'] =merged1_df['Player'].replace({'\n': ''}, regex=True)
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df.dtypes
# Out:
# Player           object
# Overs_x         float64
# Maiden          float64
# Runs             object
# Wickets         float64
# Economy_rate    float64
# Overs_y         float64
# dtype: object

# %%
merged1_df['Runs'] = merged1_df['Runs'].astype(float)

# %%
# Assuming you have a DataFrame named 'merged_df' with columns: 'Player', 'Total Overs', 'Runs'

# Add a new column 'Total Runs' with the sum of runs for each player
merged1_df['Total Runs'] = merged1_df.groupby('Player')['Runs'].transform('sum')

# The 'merged_df' DataFrame will now contain the 'Total Runs' column with the sum of runs for each player
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df['Total Wickets'] = merged1_df.groupby('Player')['Wickets'].transform('sum')
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df['Average'] = merged1_df['Total Runs'] / merged1_df['Total Wickets']
merged1_df['Average'] = merged1_df['Average'].round(2)
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
import numpy as np
merged1_df['Average'] = np.where(merged1_df['Total Wickets'] == 0, np.nan, merged1_df['Total Runs'] / merged1_df['Total Wickets'])
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df['Economy Rate'] = merged1_df['Total Runs'] / merged1_df['Overs_y']
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df['Strike Rate'] = merged1_df['Overs_y'] / merged1_df['Wickets']
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 6      Mohammed Shami      6.0     1.0  18.0      3.0          3.00     31.0
# 7      Mohammed Siraj      6.0     1.0  10.0      1.0          1.67     54.4
# 8      Shardul Thakur      6.0     1.0  26.0      1.0          4.33     36.2
# 9       Kuldeep Yadav      7.3     0.0  29.0      1.0          3.87     64.4
# 10  Washington Sundar      3.0     1.0   7.0      2.0          2.33     29.0
# ...

# %%
merged1_df = merged1_df.drop_duplicates(subset='Player')
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 14        Umran Malik      7.0     0.0  52.0      1.0          7.43      7.0
# 16   Yuzvendra Chahal      7.2     0.0  43.0      2.0          5.86      7.2
# 21    Ravindra Jadeja      9.0     0.0  46.0      2.0          5.11     19.0
# 25         Axar Patel      3.0     0.0  25.0      0.0          8.33     11.0
# 35         Avesh Khan      8.0     0.0  51.0      0.0          6.38     20.0
# ...

# %%
# Sort by average
bowling_data_avg_sorted = merged1_df.sort_values(by='Average')

# Sort by economy rate
bowling_data_eco_sorted = merged1_df.sort_values(by='Economy Rate')

# Sort by strike rate
bowling_data_sr_sorted = merged1_df.sort_values(by='Strike Rate')
bowling_data_avg_sorted
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 16   Yuzvendra Chahal      7.2     0.0  43.0      2.0          5.86      7.2
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 41      Shahbaz Ahmed     10.0     0.0  54.0      1.0          5.40     17.0
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 21    Ravindra Jadeja      9.0     0.0  46.0      2.0          5.11     19.0
# 25         Axar Patel      3.0     0.0  25.0      0.0          8.33     11.0
# 14        Umran Malik      7.0     0.0  52.0      1.0          7.43      7.0
# ...

# %%
top_avg_bowlers = bowling_data_avg_sorted.head(10)['Player']
top_avg_bowlers
# Out:
# 1        Mohammed Siraj
# 16     Yuzvendra Chahal
# 3         Kuldeep Yadav
# 4        Shardul Thakur
# 0        Mohammed Shami
# 41        Shahbaz Ahmed
# 2         Hardik Pandya
# 5     Washington Sundar
# 21      Ravindra Jadeja
# 25           Axar Patel
# Name: Player, dtype: object

# %%
for col in top_avg_bowlers.columns:
    print(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 for col in top_avg_bowlers.columns:
#       2     print(col)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
top_eco_bowlers = bowling_data_eco_sorted.head(10)['Player']
top_eco_bowlers
# Out:
# 21      Ravindra Jadeja
# 35           Avesh Khan
# 1        Mohammed Siraj
# 41        Shahbaz Ahmed
# 0        Mohammed Shami
# 3         Kuldeep Yadav
# 4        Shardul Thakur
# 16     Yuzvendra Chahal
# 5     Washington Sundar
# 2         Hardik Pandya
# Name: Player, dtype: object

# %%
top_eco_bowlers
# Out:
# 21      Ravindra Jadeja
# 35           Avesh Khan
# 1        Mohammed Siraj
# 41        Shahbaz Ahmed
# 0        Mohammed Shami
# 3         Kuldeep Yadav
# 4        Shardul Thakur
# 16     Yuzvendra Chahal
# 5     Washington Sundar
# 2         Hardik Pandya
# Name: Player, dtype: object

# %%
top_sr_bowlers = bowling_data_sr_sorted.head(10)['Player']
top_sr_bowlers
# Out:
# 16    Yuzvendra Chahal
# 14         Umran Malik
# 37        Ravi Bishnoi
# 21     Ravindra Jadeja
# 1       Mohammed Siraj
# 41       Shahbaz Ahmed
# 4       Shardul Thakur
# 2        Hardik Pandya
# 0       Mohammed Shami
# 3        Kuldeep Yadav
# Name: Player, dtype: object

# %%
# Reset the index
top_sr_bowlers = top_sr_bowlers.reset_index(drop=True)

# Create a bar plot for strike rate
plt.figure(figsize=(10, 6))
plt.bar(top_sr_bowlers.index, top_sr_bowlers.values)
plt.xlabel('Strike Rate')
plt.ylabel('Bowler')
plt.title('Top-performing Bowlers based on Strike Rate')
plt.xticks(rotation=45)
plt.show()

# %%
top_avg_bowlers.dtypes
# Out:
# dtype('O')

# %%
import matplotlib.pyplot as plt

# %%
# Assuming your DataFrame is named 'top_avg_bowlers'

# Reset the index
top_avg_bowlers = top_avg_bowlers.reset_index(drop=True)

# Assuming your DataFrame is named 'top_avg_bowlers'

# Create a bar plot for average

plt.figure(figsize=(10, 6))
plt.bar(top_avg_bowlers.index, top_avg_bowlers.values)
plt.xlabel('Average')
plt.ylabel('Bowler')
plt.title('Top-performing Bowlers based on Average')
plt.xticks(rotation=45)
plt.show()

# %%
#asc order
top_avg_bowlers
# Out:
# 0       Mohammed Siraj
# 1     Yuzvendra Chahal
# 2        Kuldeep Yadav
# 3       Shardul Thakur
# 4       Mohammed Shami
# 5        Shahbaz Ahmed
# 6        Hardik Pandya
# 7    Washington Sundar
# 8      Ravindra Jadeja
# 9           Axar Patel
# Name: Player, dtype: object

# %%
# Assuming your DataFrame is named 'top_avg_bowlers'

# Reset the index
top_eco_bowlers_bowlers = top_eco_bowlers.reset_index(drop=True)

# Assuming your DataFrame is named 'top_avg_bowlers'

# Create a bar plot for eco_rate

plt.figure(figsize=(10, 6))
plt.bar(top_eco_bowlers.index, top_eco_bowlers.values)
plt.xlabel('Economy Rate')
plt.ylabel('Bowler')
plt.title('Top Bowlers based on Economy Rate')
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming top_strike_rate_bowlers is a Series containing strike rate values

# Create a bar plot for strike rate
plt.figure(figsize=(10, 6))
plt.bar(top_sr_bowlers.index, top_sr_bowlers.values)
plt.xlabel('Strike Rate')
plt.ylabel('Bowlers')
plt.title('Top Bowlers based on Strike Rate')
plt.xticks(rotation=45)
plt.show()

# %%
concatenated2_df
# Out:
#                Player               Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*    c Mitchell b Tickner   34          38     4     2
# 1        Shubman Gill    c Phillips b Shipley  208         149    19     9
# 2         Virat Kohli               b Santner    8          10     1     0
# 3     Ishan Kishanâ€   c â€ Latham b Ferguson    5          14     0     0
# 4    Suryakumar Yadav    c Santner b Mitchell   31          26     4     0
# ..                ...                     ...  ...         ...   ...   ...
# 92     Shardul Thakur                       -    0           0     0     0
# 93  Washington Sundar                       -    0           0     0     0
# 94      Shahbaz Ahmed                       -    0           0     0     0
# 95      Kuldeep Yadav                       -    0           0     0     0
# 96         Avesh Khan                       -    0           0     0     0
#
#    Strike Rate
# 0        89.47
# 1        139.6
# 2         80.0
# ...

# %%
concatenated2_df['Player'] = concatenated2_df['Player'].replace({'â€': ''}, regex=True)
concatenated2_df['Dismissal'] = concatenated2_df['Dismissal'].replace({'â€': ''}, regex=True)
concatenated2_df
# Out:
#                Player             Dismissal Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*  c Mitchell b Tickner   34          38     4     2
# 1        Shubman Gill  c Phillips b Shipley  208         149    19     9
# 2         Virat Kohli             b Santner    8          10     1     0
# 3       Ishan Kishan   c  Latham b Ferguson    5          14     0     0
# 4    Suryakumar Yadav  c Santner b Mitchell   31          26     4     0
# ..                ...                   ...  ...         ...   ...   ...
# 92     Shardul Thakur                     -    0           0     0     0
# 93  Washington Sundar                     -    0           0     0     0
# 94      Shahbaz Ahmed                     -    0           0     0     0
# 95      Kuldeep Yadav                     -    0           0     0     0
# 96         Avesh Khan                     -    0           0     0     0
#
#    Strike Rate
# 0        89.47
# 1        139.6
# 2         80.0
# 3        35.71
# ...

# %%
concatenated2_df.head(10)
# Out:
#               Player             Dismissal  Runs Balls Faced Fours Sixes  \
# 0      Rohit Sharma*  c Mitchell b Tickner    34          38     4     2
# 1       Shubman Gill  c Phillips b Shipley   208         149    19     9
# 2        Virat Kohli             b Santner     8          10     1     0
# 3      Ishan Kishan   c  Latham b Ferguson     5          14     0     0
# 4   Suryakumar Yadav  c Santner b Mitchell    31          26     4     0
# 5      Hardik Pandya            b Mitchell    28          38     3     0
# 6  Washington Sundar         lbw b Shipley    12          14     0     0
# 7     Shardul Thakur               run out     3           3     0     0
# 8      Kuldeep Yadav               not out     5           6     0     0
# 9     Mohammed Shami               not out     2           2     0     0
#
#   Strike Rate
# 0       89.47
# 1       139.6
# 2        80.0
# 3       35.71
# 4      119.23
# 5       73.68
# 6       85.71
# 7       100.0
# 8       83.33
# ...

# %% [markdown]
# **Who are the leading run-scorers and batsmen with the highest batting average and strike rate?**

# %%
total_runs = concatenated2_df.groupby('Player')['Runs'].sum().reset_index()
innings_played = concatenated2_df.groupby('Player').size().reset_index(name='Innings')
batting_avg = total_runs.merge(innings_played, on='Player')
batting_avg['Average'] = batting_avg['Runs'] / batting_avg['Innings']
strike_rate = concatenated2_df.groupby('Player')['Strike Rate'].mean().reset_index()
sorted_runs = total_runs.sort_values(by='Runs', ascending=False)
sorted_avg = batting_avg.sort_values(by='Average', ascending=False)
sorted_sr = strike_rate.sort_values(by='Strike Rate', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[494], line 1
# ----> 1 total_runs = concatenated2_df.groupby('Player')['Runs'].sum().reset_index()
#       2 innings_played = concatenated2_df.groupby('Player').size().reset_index(name='Innings')
#       3 batting_avg = total_runs.merge(innings_played, on='Player')
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py:2456, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2451 else:
#    2452     # If we are grouping on categoricals we want unobserved categories to
#    2453     # return zero, rather than the default of NaN which the reindexing in
#    2454     # _agg_general() returns. GH #31422
#    2455     with com.temp_setattr(self, "observed", True):
# -> 2456         result = self._agg_general(
#    2457             numeric_only=numeric_only,
# ...

# %%
concatenated2_df.dtypes
# Out:
# Player         object
# Dismissal      object
# Runs           object
# Balls Faced    object
# Fours          object
# Sixes          object
# Strike Rate    object
# dtype: object

# %%
invalid_values = concatenated2_df['Runs'].unique()
invalid_values
# Out:
# array([34, 208, 8, 5, 31, 28, 12, 3, 2, 0, '51', '40', '11', '8', '9',
#        '13', '3', '1', 'O', '0', 20.0, 4.0, 75.0, 25.0, 45.0, 13.0, 9.0,
#        1.0, 16.0, 29.0, 30, 37, 54, 32, 40, 18, 6, 14, 19.0, 50.0, 86.0,
#        33.0, 93.0, 113.0, nan, 49.0, 10.0], dtype=object)

# %%
concatenated2_df['Runs'] = concatenated2_df['Runs'].replace('0', np.nan)
concatenated2_df['Runs'] = concatenated2_df['Runs'].replace('O', np.nan)

# %%
concatenated2_df['Runs'] = concatenated2_df['Runs'].astype(int)
concatenated2_df['Strike Rate'] = concatenated2_df['Strike Rate'].astype(float)

# %%
concatenated2_df['Runs'] = concatenated2_df['Runs'].fillna(0).astype(int)

# %%
total_runs = concatenated2_df.groupby('Player')['Runs'].sum().reset_index()
innings_played = concatenated2_df.groupby('Player').size().reset_index(name='Innings')
batting_avg = total_runs.merge(innings_played, on='Player')
batting_avg['Average'] = batting_avg['Runs'] / batting_avg['Innings']
strike_rate = concatenated2_df.groupby('Player')['Strike Rate'].mean().reset_index()
sorted_runs = total_runs.sort_values(by='Runs', ascending=False)
sorted_avg = batting_avg.sort_values(by='Average', ascending=False)
sorted_sr = strike_rate.sort_values(by='Strike Rate', ascending=False)

# %%
total_runs = concatenated2_df.groupby('Player')['Runs'].sum().reset_index()
innings_played = concatenated2_df.groupby('Player').size().reset_index(name='Innings')
batting_avg = total_runs.merge(innings_played, on='Player')
batting_avg['Average'] = batting_avg['Runs'] / batting_avg['Innings']
strike_rate = concatenated2_df.groupby('Player')['Strike Rate'].mean().reset_index()
sorted_runs = total_runs.sort_values(by='Runs', ascending=False)
sorted_avg = batting_avg.sort_values(by='Average', ascending=False)
sorted_sr = strike_rate.sort_values(by='Strike Rate', ascending=False)

# %%
#Leading Run Scorer
leading_run_scorers = sorted_runs.head(10).reset_index(drop=True)
#Batsmen with Highest Batting Average:
batsmen_highest_avg = sorted_avg.head(10).reset_index(drop=True)
#Batsmen with Highest Strike Rate:
batsmen_highest_sr = sorted_sr.head(10).reset_index(drop=True)

# %%
leading_run_scorers
#batsman leading run-scorer = Shubman Gill
# Out:
#             Player  Runs
# 0     Shubman Gill   398
# 1     Shreyas Iyer   191
# 2     Ishan Kishan   126
# 3         KL Rahul   116
# 4      Virat Kohli   111
# 5    Hardik Pandya    97
# 6     Sanju Samson    86
# 7    Rohit Sharma*    85
# 8  Ravindra Jadeja    79
# 9     Rohit Sharma    43

# %%
import matplotlib.pyplot as plt

leading_run_scorers.plot(x='Player', y='Runs', kind='bar', figsize=(10, 6))
plt.xlabel('Player')
plt.ylabel('Runs')
plt.title('Leading Run Scorers')
plt.xticks(rotation=45)
plt.show()

# %%
batsmen_highest_avg
#batsman with highest avg = Sanju
# Out:
#             Player  Runs  Innings    Average
# 0     Sanju Samson    86        1  86.000000
# 1     Shreyas Iyer   191        3  63.666667
# 2     Shubman Gill   398        9  44.222222
# 3    Rohit Sharma*    85        2  42.500000
# 4         KL Rahul   116        3  38.666667
# 5     Ishan Kishan   126        4  31.500000
# 6  Ravindra Jadeja    79        3  26.333333
# 7     Rohit Sharma    43        2  21.500000
# 8  Ruturaj Gaikwad    19        1  19.000000
# 9      Virat Kohli   111        6  18.500000

# %%
import matplotlib.pyplot as plt

batsmen_highest_avg.plot(x='Player', y='Average', kind='bar', figsize=(10, 6))
plt.xlabel('Player')
plt.ylabel('Average')
plt.title('Batsmen with Highest Average')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

batsmen_highest_avg.plot(x='Player', y='Average', kind='line', marker='*', figsize=(10, 6))
plt.xlabel('Player')
plt.ylabel('Average')
plt.title('Batsmen with Highest Average')
plt.xticks(rotation=45)
plt.show()

# %%
batsmen_highest_sr
#batsman with highest sr = sanju samson
# Out:
#            Player  Strike Rate
# 0    Ravi Bishnoi   200.000000
# 1    Sanju Samson   136.510000
# 2    Rohit Sharma   131.570000
# 3    Shreyas Iyer   119.560000
# 4  Rohit Sharma *   118.820000
# 5   Rohit Sharma*    95.735000
# 6     Virat Kohli    90.593333
# 7    Shubman Gill    81.688889
# 8      Axar Patel    75.000000
# 9        KL Rahul    73.806667

# %%
import matplotlib.pyplot as plt

batsmen_highest_sr.plot(x='Player', y='Strike Rate', kind='bar', figsize=(10, 6))
plt.xlabel('Player')
plt.ylabel('Strike Rate')
plt.title('Batsmen with Highest Strike Rate')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

batsmen_highest_sr.plot(x='Player', y='Strike Rate', kind='line', marker='*',figsize=(10, 6))
plt.xlabel('Player')
plt.ylabel('Strike Rate')
plt.title('Batsmen with Highest Strike Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Identify consistent performers who have excelled in both batting and bowling.***

# %%
concatenated2_df.head(50)
# Out:
#                Player                Dismissal  Runs Balls Faced Fours Sixes  \
# 0       Rohit Sharma*     c Mitchell b Tickner    34          38     4     2
# 1        Shubman Gill     c Phillips b Shipley   208         149    19     9
# 2         Virat Kohli                b Santner     8          10     1     0
# 3       Ishan Kishan      c  Latham b Ferguson     5          14     0     0
# 4    Suryakumar Yadav     c Santner b Mitchell    31          26     4     0
# 5       Hardik Pandya               b Mitchell    28          38     3     0
# 6   Washington Sundar            lbw b Shipley    12          14     0     0
# 7      Shardul Thakur                  run out     3           3     0     0
# 8       Kuldeep Yadav                  not out     5           6     0     0
# 9      Mohammed Shami                  not out     2           2     0     0
# 10     Mohammed Siraj                        -     0           0     0     0
# ...

# %%
concatenated2_df['Player'] = concatenated2_df['Player'].str.rstrip('*')
concatenated2_df
# Out:
#                Player             Dismissal  Runs Balls Faced Fours Sixes  \
# 0        Rohit Sharma  c Mitchell b Tickner    34          38     4     2
# 1        Shubman Gill  c Phillips b Shipley   208         149    19     9
# 2         Virat Kohli             b Santner     8          10     1     0
# 3       Ishan Kishan   c  Latham b Ferguson     5          14     0     0
# 4    Suryakumar Yadav  c Santner b Mitchell    31          26     4     0
# ..                ...                   ...   ...         ...   ...   ...
# 92     Shardul Thakur                     -     0           0     0     0
# 93  Washington Sundar                     -     0           0     0     0
# 94      Shahbaz Ahmed                     -     0           0     0     0
# 95      Kuldeep Yadav                     -     0           0     0     0
# 96         Avesh Khan                     -     0           0     0     0
#
#     Strike Rate
# 0         89.47
# 1        139.60
# 2         80.00
# ...

# %%
concatenated2_df = concatenated2_df.drop('Runs_y',axis = 1)
concatenated2_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[509], line 1
# ----> 1 concatenated2_df = concatenated2_df.drop('Runs_y',axis = 1)
#       2 concatenated2_df
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
concatenated2_df.dtypes
# Out:
# Player          object
# Dismissal       object
# Runs             int32
# Balls Faced     object
# Fours           object
# Sixes           object
# Strike Rate    float64
# dtype: object

# %%
# Assuming the dataframe is named 'df' and the column to be converted is named 'column_name'

# Replace non-numeric values with NaN
concatenated2_df['Fours'] = pd.to_numeric(concatenated2_df['Fours'], errors='coerce')

# Convert the column to float
concatenated2_df['Fours'] = concatenated2_df['Fours'].astype(float)

# Print the updated dataframe with the changed datatype
print(concatenated2_df.dtypes)
# Out:
# Player          object
# Dismissal       object
# Runs_x           int32
# Balls Faced     object
# Fours          float64
# Sixes           object
# Strike Rate    float64
# Runs_y           int32
# dtype: object

# %%
import numpy as np

# Assuming the dataframe is named 'df' and the column to be changed is named 'column_name'

# Replace non-finite values with NaN
concatenated2_df['Fours'] = concatenated2_df['Fours'].replace([np.inf, -np.inf], np.nan)

# Convert the column to float
concatenated2_df['Fours'] = concatenated2_df['Fours'].astype(float)

# Convert the column to int, while handling NaN values
concatenated2_df['Fours'] = concatenated2_df['Fours'].fillna(0).astype(int)

# Print the updated dataframe with the changed datatype
print(concatenated2_df.dtypes)
# Out:
# Player          object
# Dismissal       object
# Runs_x           int32
# Balls Faced     object
# Fours            int32
# Sixes           object
# Strike Rate    float64
# Runs_y           int32
# dtype: object

# %%
concatenated2_df
# Out:
#                Player             Dismissal  Runs_x Balls Faced  Fours Sixes  \
# 0        Rohit Sharma  c Mitchell b Tickner      34          38      4     2
# 1        Shubman Gill  c Phillips b Shipley     208         149     19     9
# 2         Virat Kohli             b Santner       8          10      1     0
# 3       Ishan Kishan   c  Latham b Ferguson       5          14      0     0
# 4    Suryakumar Yadav  c Santner b Mitchell      31          26      4     0
# ..                ...                   ...     ...         ...    ...   ...
# 92     Shardul Thakur                     -       0           0      0     0
# 93  Washington Sundar                     -       0           0      0     0
# 94      Shahbaz Ahmed                     -       0           0      0     0
# 95      Kuldeep Yadav                     -       0           0      0     0
# 96         Avesh Khan                     -       0           0      0     0
#
#     Strike Rate  Runs_y
# ...

# %%
concatenated2_df['Sixes'] = concatenated2_df['Sixes'].astype(float)
concatenated2_df.dtypes
# Out:
# Player          object
# Dismissal       object
# Runs_x           int32
# Balls Faced     object
# Fours_x          int32
# Sixes          float64
# Strike Rate    float64
# Runs_y           int32
# Fours_y          int32
# dtype: object

# %%
concatenated2_df['Balls Faced'] = concatenated2_df['Balls Faced'].astype(float)
concatenated2_df.dtypes
# Out:
# Player          object
# Dismissal       object
# Runs_x           int32
# Balls Faced    float64
# Fours_x          int32
# Sixes_x        float64
# Strike Rate    float64
# Runs_y           int32
# Fours_y          int32
# Sixes_y        float64
# dtype: object

# %%
# Assuming the original dataframe is named 'batting_data'

# Step 1: Identify the key column(s)
key_columns = ['Player']  # Replace 'Player' with the actual column name that uniquely identifies each record

# Step 2: Remove duplicates
# unique_batting_data = concatenated2_df.drop_duplicates(subset=key_columns)

# Step 3: Sum up the scores

# summed_scores = concatenated2_df.groupby(key_columns)['Runs'].sum().reset_index()
#summed_fours = concatenated2_df.groupby(key_columns)['Fours'].sum().reset_index()
#summed_sixes = concatenated2_df.groupby(key_columns)['Sixes'].sum().reset_index()
#summed_balls = concatenated2_df.groupby(key_columns)['Balls Faced'].sum().reset_index()
merged3_df = pd.merge(summed_scores, summed_balls, on=key_columns)
merged3_df['Strike Rate'] = (merged3_df['Runs'] / merged3_df['Balls Faced']) * 100



# Step 4: Merge summed scores back into the original dataframe

# concatenated2_df = concatenated2_df.merge(summed_scores, on=key_columns, how='left')
#concatenated2_df = concatenated2_df.merge(summed_fours, on=key_columns, how='left')
#concatenated2_df = concatenated2_df.merge(summed_sixes, on=key_columns, how='left')
concatenated2_df = pd.merge(concatenated2_df, merged3_df[key_columns + ['Strike Rate']], on=key_columns, how='left')


# Print the updated dataframe
# print(batting_data)
concatenated2_df
# Out:
#                Player             Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0        Rohit Sharma  c Mitchell b Tickner      34           38.0        4
# 1        Shubman Gill  c Phillips b Shipley     208          149.0       19
# 2         Virat Kohli             b Santner       8           10.0        1
# 3       Ishan Kishan   c  Latham b Ferguson       5           14.0        0
# 4    Suryakumar Yadav  c Santner b Mitchell      31           26.0        4
# ..                ...                   ...     ...            ...      ...
# 92     Shardul Thakur                     -       0            0.0        0
# 93  Washington Sundar                     -       0            0.0        0
# 94      Shahbaz Ahmed                     -       0            0.0        0
# 95      Kuldeep Yadav                     -       0            0.0        0
# 96         Avesh Khan                     -       0            0.0        0
#
# ...

# %%
concatenated2_df
# Out:
#                Player             Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0        Rohit Sharma  c Mitchell b Tickner      34           38.0        4
# 1        Shubman Gill  c Phillips b Shipley     208          149.0       19
# 2         Virat Kohli             b Santner       8           10.0        1
# 3       Ishan Kishan   c  Latham b Ferguson       5           14.0        0
# 4    Suryakumar Yadav  c Santner b Mitchell      31           26.0        4
# ..                ...                   ...     ...            ...      ...
# 92     Shardul Thakur                     -       0            0.0        0
# 93  Washington Sundar                     -       0            0.0        0
# 94      Shahbaz Ahmed                     -       0            0.0        0
# 95      Kuldeep Yadav                     -       0            0.0        0
# 96         Avesh Khan                     -       0            0.0        0
#
# ...

# %%
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 14        Umran Malik      7.0     0.0  52.0      1.0          7.43      7.0
# 16   Yuzvendra Chahal      7.2     0.0  43.0      2.0          5.86      7.2
# 21    Ravindra Jadeja      9.0     0.0  46.0      2.0          5.11     19.0
# 25         Axar Patel      3.0     0.0  25.0      0.0          8.33     11.0
# 35         Avesh Khan      8.0     0.0  51.0      0.0          6.38     20.0
# ...

# %%
batting_avg
# Out:
#                Player  Runs  Innings    Average
# 0          Avesh Khan     3        4   0.750000
# 1          Axar Patel    31        2  15.500000
# 2       Hardik Pandya    97        6  16.166667
# 3        Ishan Kishan   126        4  31.500000
# 4       Ishan Kishant     1        1   1.000000
# 5       Ishan Kishan     13        2   6.500000
# 6            KL Rahul   116        3  38.666667
# 7       Kuldeep Yadav    15        9   1.666667
# 8      Mohammed Shami    16        5   3.200000
# 9      Mohammed Siraj     3        6   0.500000
# 10   Mohammed Siraj       0        1   0.000000
# 11       Ravi Bishnoi     4        1   4.000000
# 12    Ravindra Jadeja    79        3  26.333333
# 13       Rohit Sharma    43        2  21.500000
# 14     Rohit Sharma *     9        1   9.000000
# 15      Rohit Sharma*    85        2  42.500000
# 16    Ruturaj Gaikwad    19        1  19.000000
# 17       Sanju Samson    86        1  86.000000
# 18      Sanju Samson     32        2  16.000000
# ...

# %%
innings_played
# Out:
#                Player  Innings
# 0          Avesh Khan        4
# 1          Axar Patel        2
# 2       Hardik Pandya        6
# 3        Ishan Kishan        4
# 4       Ishan Kishant        1
# 5       Ishan Kishan         2
# 6            KL Rahul        3
# 7       Kuldeep Yadav        9
# 8      Mohammed Shami        5
# 9      Mohammed Siraj        6
# 10   Mohammed Siraj          1
# 11       Ravi Bishnoi        1
# 12    Ravindra Jadeja        3
# 13       Rohit Sharma        2
# 14     Rohit Sharma *        1
# 15      Rohit Sharma*        2
# 16    Ruturaj Gaikwad        1
# 17       Sanju Samson        1
# 18      Sanju Samson         2
# 19      Shahbaz Ahmed        2
# 20     Shardul Thakur        7
# 21    Shikhar Dhawan         1
# 22       Shreyas Iyer        3
# 23       Shubman Gill        9
# 24   Suryakumar Yadav        6
# 25        Umran Malik        1
# 26        Virat Kohli        6
# 27  Washington Sundar        5
# 28   Yuzvendra Chahal        1

# %%
bowling_data_avg_sorted
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 16   Yuzvendra Chahal      7.2     0.0  43.0      2.0          5.86      7.2
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 41      Shahbaz Ahmed     10.0     0.0  54.0      1.0          5.40     17.0
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 21    Ravindra Jadeja      9.0     0.0  46.0      2.0          5.11     19.0
# 25         Axar Patel      3.0     0.0  25.0      0.0          8.33     11.0
# 14        Umran Malik      7.0     0.0  52.0      1.0          7.43      7.0
# ...

# %%
batsmen_highest_sr
# Out:
#            Player  Strike Rate
# 0    Ravi Bishnoi   200.000000
# 1    Sanju Samson   136.510000
# 2    Rohit Sharma   131.570000
# 3    Shreyas Iyer   119.560000
# 4  Rohit Sharma *   118.820000
# 5   Rohit Sharma*    95.735000
# 6     Virat Kohli    90.593333
# 7    Shubman Gill    81.688889
# 8      Axar Patel    75.000000
# 9        KL Rahul    73.806667

# %%
concatenated2_df
# Out:
#                Player             Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0        Rohit Sharma  c Mitchell b Tickner      34           38.0        4
# 1        Shubman Gill  c Phillips b Shipley     208          149.0       19
# 2         Virat Kohli             b Santner       8           10.0        1
# 3       Ishan Kishan   c  Latham b Ferguson       5           14.0        0
# 4    Suryakumar Yadav  c Santner b Mitchell      31           26.0        4
# ..                ...                   ...     ...            ...      ...
# 92     Shardul Thakur                     -       0            0.0        0
# 93  Washington Sundar                     -       0            0.0        0
# 94      Shahbaz Ahmed                     -       0            0.0        0
# 95      Kuldeep Yadav                     -       0            0.0        0
# 96         Avesh Khan                     -       0            0.0        0
#
# ...

# %%
concatenated2_df.drop_duplicates(subset='Player', inplace=True)
concatenated2_df
# Out:
#                Player             Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0        Rohit Sharma  c Mitchell b Tickner      34           38.0        4
# 1        Shubman Gill  c Phillips b Shipley     208          149.0       19
# 2         Virat Kohli             b Santner       8           10.0        1
# 3       Ishan Kishan   c  Latham b Ferguson       5           14.0        0
# 4    Suryakumar Yadav  c Santner b Mitchell      31           26.0        4
# 5       Hardik Pandya            b Mitchell      28           38.0        3
# 6   Washington Sundar         lbw b Shipley      12           14.0        0
# 7      Shardul Thakur               run out       3            3.0        0
# 8       Kuldeep Yadav               not out       5            6.0        0
# 9      Mohammed Shami               not out       2            2.0        0
# 10     Mohammed Siraj                     -       0            0.0        0
# ...

# %%
concatenated_df
# Out:
#                 Player  Overs  Maiden  Runs  Wickets  Economy_rate
# 0       Mohammed Shami   10.0     1.0  69.0      1.0          6.90
# 1       Mohammed Siraj   10.0     2.0  46.0      4.0          4.60
# 2        Hardik Pandya    7.0     0.0  70.0      1.0         10.00
# 3        Kuldeep Yadav    8.0     1.0  43.0      2.0          5.38
# 4       Shardul Thakur    7.2     0.0  54.0      2.0          7.36
# 5    Washington Sundar    7.0     0.0  50.0      0.0          7.14
# 6       Mohammed Shami    6.0     1.0  18.0      3.0          3.00
# 7       Mohammed Siraj    6.0     1.0  10.0      1.0          1.67
# 8       Shardul Thakur    6.0     1.0  26.0      1.0          4.33
# 9        Kuldeep Yadav    7.3     0.0  29.0      1.0          3.87
# 10   Washington Sundar    3.0     1.0   7.0      2.0          2.33
# 11       Hardik Pandya    6.0     0.0    37      1.0          6.17
# 12   Washington Sundar    6.0     0.0    49      0.0          8.17
# ...

# %%
merged1_df
# Out:
#                Player  Overs_x  Maiden  Runs  Wickets  Economy_rate  Overs_y  \
# 0      Mohammed Shami     10.0     1.0  69.0      1.0          6.90     31.0
# 1      Mohammed Siraj     10.0     2.0  46.0      4.0          4.60     54.4
# 2       Hardik Pandya      7.0     0.0  70.0      1.0         10.00     27.0
# 3       Kuldeep Yadav      8.0     1.0  43.0      2.0          5.38     64.4
# 4      Shardul Thakur      7.2     0.0  54.0      2.0          7.36     36.2
# 5   Washington Sundar      7.0     0.0  50.0      0.0          7.14     29.0
# 14        Umran Malik      7.0     0.0  52.0      1.0          7.43      7.0
# 16   Yuzvendra Chahal      7.2     0.0  43.0      2.0          5.86      7.2
# 21    Ravindra Jadeja      9.0     0.0  46.0      2.0          5.11     19.0
# 25         Axar Patel      3.0     0.0  25.0      0.0          8.33     11.0
# 35         Avesh Khan      8.0     0.0  51.0      0.0          6.38     20.0
# ...

# %%
concatenated3_df = pd.merge(concatenated2_df,innings_played, on='Player')
concatenated3_df
# Out:
#                Player             Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0        Rohit Sharma  c Mitchell b Tickner      34           38.0        4
# 1        Shubman Gill  c Phillips b Shipley     208          149.0       19
# 2         Virat Kohli             b Santner       8           10.0        1
# 3       Ishan Kishan   c  Latham b Ferguson       5           14.0        0
# 4    Suryakumar Yadav  c Santner b Mitchell      31           26.0        4
# 5       Hardik Pandya            b Mitchell      28           38.0        3
# 6   Washington Sundar         lbw b Shipley      12           14.0        0
# 7      Shardul Thakur               run out       3            3.0        0
# 8       Kuldeep Yadav               not out       5            6.0        0
# 9      Mohammed Shami               not out       2            2.0        0
# 10     Mohammed Siraj                     -       0            0.0        0
# ...

# %%
merged_data_2 = pd.merge(concatenated3_df, concatenated_df, on='Player')
merged_data_2
# Out:
#                Player          Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0       Hardik Pandya         b Mitchell      28           38.0        3
# 1       Hardik Pandya         b Mitchell      28           38.0        3
# 2       Hardik Pandya         b Mitchell      28           38.0        3
# 3       Hardik Pandya         b Mitchell      28           38.0        3
# 4       Hardik Pandya         b Mitchell      28           38.0        3
# 5   Washington Sundar      lbw b Shipley      12           14.0        0
# 6   Washington Sundar      lbw b Shipley      12           14.0        0
# 7   Washington Sundar      lbw b Shipley      12           14.0        0
# 8   Washington Sundar      lbw b Shipley      12           14.0        0
# 9   Washington Sundar      lbw b Shipley      12           14.0        0
# 10     Shardul Thakur            run out       3            3.0        0
# 11     Shardul Thakur            run out       3            3.0        0
# ...

# %%
unique2_values = merged_data_2['Wickets'].unique()
#print(unique2_values)
import numpy as np

merged_data_2.replace(0, np.nan, inplace=True)

# %%
merged_data_2.dtypes
# Out:
# Player            object
# Dismissal         object
# Runs_x           float64
# Balls Faced_x    float64
# Fours_x          float64
# Sixes_x          float64
# Strike Rate_x    float64
# Runs_y           float64
# Fours_y          float64
# Sixes_y          float64
# Balls Faced_y    float64
# Strike Rate_y    float64
# Innings            int64
# Overs            float64
# Maiden           float64
# Runs              object
# Wickets          float64
# Economy_rate     float64
# Average          float64
# dtype: object

# %%
merged_data_2['Runs'] = merged_data_2['Runs'].astype(float)
merged_data_2
# Out:
#                Player          Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 1       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 2       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 3       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 4       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 5   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 6   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 7   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 8   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 9   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 10     Shardul Thakur            run out     3.0            3.0      NaN
# 11     Shardul Thakur            run out     3.0            3.0      NaN
# ...

# %%
import numpy as np

# Check if the divisor is zero before performing division
mask = merged_data_2['Innings'] != 0
merged_data_2.loc[mask, 'Average'] = merged_data_2['Runs_y'] / merged_data_2['Innings']
merged_data_2.loc[~mask, 'Average'] = np.nan  # Set NaN for players with 0 innings

mask = merged_data_2['Wickets'] != 0
merged_data_2.loc[mask, 'Bowling_Average'] = merged_data_2['Runs'] / merged_data_2['Wickets']
merged_data_2.loc[~mask, 'Bowling_Average'] = np.nan  # Set NaN for players with 0 wickets

# Define criteria for consistent performers
batting_avg_threshold = 35
bowling_avg_threshold = 35
economy_rate_threshold = 5.5

# Filter the merged DataFrame based on the criteria
consistent_performers = merged_data_2[(merged_data_2['Average'] > batting_avg_threshold) & (merged_data_2['Bowling_Average'] < bowling_avg_threshold) & (merged_data_2['Economy_rate'] < economy_rate_threshold)]

# Print the consistent performers
print(consistent_performers)
# Out:
# Empty DataFrame
# Columns: [Player, Dismissal, Runs_x, Balls Faced_x, Fours_x, Sixes_x, Strike Rate_x, Runs_y, Fours_y, Sixes_y, Balls Faced_y, Strike Rate_y, Innings, Overs, Maiden, Runs, Wickets, Economy_rate, Average, Bowling_Average]
# Index: []

# %%
merged_data_2
# Out:
#                Player          Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 0       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 1       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 2       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 3       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 4       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 5   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 6   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 7   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 8   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 9   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 10     Shardul Thakur            run out     3.0            3.0      NaN
# 11     Shardul Thakur            run out     3.0            3.0      NaN
# ...

# %% [markdown]
# **Determine the ideal batting order based on individual player performance.**

# %%
import pandas as pd

# Assuming you have a DataFrame called 'merged_data_2' with columns 'Player', 'Batting_Average', 'Strike_Rate'

# Sort the players based on batting average in descending order
merged_data_2.sort_values(by='Average', ascending=False, inplace=True)

# Create a new column 'Order' to store the batting order
merged_data_2['Order'] = range(1, len(merged_data_2) + 1)

# Adjust the batting order based on strike rate and playing style
merged_data_2.loc[merged_data_2['Strike Rate_y'] > 100, 'Order'] -= 1

# Sort the players based on the adjusted order
merged_data_2.sort_values(by='Order', inplace=True)

# Display the ideal batting order
print(merged_data_2[['Player', 'Order']])
# Out:
#                Player  Order
# 40    Ravindra Jadeja      1
# 0       Hardik Pandya      2
# 42         Axar Patel      3
# 15     Shardul Thakur      4
# 46       Ravi Bishnoi      4
# 29     Mohammed Shami      5
# 8   Washington Sundar      7
# 17      Kuldeep Yadav      8
# 43         Avesh Khan      9
# 38     Mohammed Siraj     10
# 47      Shahbaz Ahmed     11

# %%
merged_data_2.drop_duplicates(subset='Player', inplace=True)
merged_data_2
# Out:
#                Player          Dismissal  Runs_x  Balls Faced_x  Fours_x  \
# 40    Ravindra Jadeja            not out    45.0           69.0      5.0
# 0       Hardik Pandya         b Mitchell    28.0           38.0      3.0
# 42         Axar Patel            not out    29.0           29.0      1.0
# 15     Shardul Thakur            run out     3.0            3.0      NaN
# 46       Ravi Bishnoi            not out     4.0            2.0      NaN
# 29     Mohammed Shami            not out     2.0            2.0      NaN
# 8   Washington Sundar      lbw b Shipley    12.0           14.0      NaN
# 17      Kuldeep Yadav            not out     5.0            6.0      NaN
# 43         Avesh Khan  c Bavuma b Rabada     3.0            6.0      NaN
# 38     Mohammed Siraj                  -     NaN            NaN      NaN
# 47      Shahbaz Ahmed                NaN     NaN            NaN      NaN
#
#     Sixes_x  Strike Rate_x  Runs_y  Fours_y  Sixes_y  ...  Strike Rate_y  \
# ...

# %%
plt.figure(figsize=(8, 6))
plt.bar(merged_data_2['Order'], merged_data_2['Player'], color='blue')
plt.xlabel('Batting Order')
plt.ylabel('Batting Player')
plt.title('Ideal Batting Order')
plt.xticks(rotation=45)  # Rotate the labels by 45 degrees
plt.tight_layout() 
plt.show()
