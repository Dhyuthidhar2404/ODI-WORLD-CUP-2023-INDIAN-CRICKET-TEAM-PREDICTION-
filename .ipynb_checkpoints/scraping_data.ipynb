# %%
import pandas as pd
data =pd.read_csv("output1.csv")
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 data =pd.read_csv("output1.csv")
#       3 data
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
import chardet

with open('output1.csv', 'rb') as f:
    result = chardet.detect(f.read())
    
print(result['encoding'])
# Out:
# Windows-1252

# %%
import pandas as pd

df = pd.read_csv('output1.csv', encoding='Windows-1252')
df
# Out:
#                         Jason Roy                   b  Bumrah              0  \
# 0                  Jonny Bairstow           c †Pant b  Bumrah              7
# 1                        Joe Root           c †Pant b  Bumrah              0
# 2                      Ben Stokes   c †Pant b  Mohammed Shami              0
# 3                   Jos Buttler*†  c  Yadav b  Mohammed Shami             30
# 4                Liam Livingstone                   b  Bumrah              0
# 5                       Moeen Ali      c & b  Prasidh Krishna             14
# 6                    David Willey                   b  Bumrah             21
# 7                   Craig Overton           b  Mohammed Shami              8
# 8                    Brydon Carse                   b  Bumrah             15
# 9                    Reece Topley                     not out              6
# 10                         Extras                 (lb 2, w 7)              9
# ...

# %%
df.drop([44,45,43],axis=0,inplace=True)

# %%
df
# Out:
#             Jason Roy                   b  Bumrah              0  \
# 0      Jonny Bairstow           c †Pant b  Bumrah              7
# 1            Joe Root           c †Pant b  Bumrah              0
# 2          Ben Stokes   c †Pant b  Mohammed Shami              0
# 3       Jos Buttler*†  c  Yadav b  Mohammed Shami             30
# 4    Liam Livingstone                   b  Bumrah              0
# 5           Moeen Ali      c & b  Prasidh Krishna             14
# 6        David Willey                   b  Bumrah             21
# 7       Craig Overton           b  Mohammed Shami              8
# 8        Brydon Carse                   b  Bumrah             15
# 9        Reece Topley                     not out              6
# 10             Extras                 (lb 2, w 7)              9
# 11                NaN                         NaN            NaN
# 12           1-6  Roy                   2-6  Root    3-7  Stokes
# ...

# %%
df.drop(df.index[34:42],inplace=True)
df
# Out:
#             Jason Roy                   b  Bumrah              0  \
# 0      Jonny Bairstow           c †Pant b  Bumrah              7
# 1            Joe Root           c †Pant b  Bumrah              0
# 2          Ben Stokes   c †Pant b  Mohammed Shami              0
# 3       Jos Buttler*†  c  Yadav b  Mohammed Shami             30
# 4    Liam Livingstone                   b  Bumrah              0
# 5           Moeen Ali      c & b  Prasidh Krishna             14
# 6        David Willey                   b  Bumrah             21
# 7       Craig Overton           b  Mohammed Shami              8
# 8        Brydon Carse                   b  Bumrah             15
# 9        Reece Topley                     not out              6
# 10             Extras                 (lb 2, w 7)              9
# 11                NaN                         NaN            NaN
# 12           1-6  Roy                   2-6  Root    3-7  Stokes
# ...
